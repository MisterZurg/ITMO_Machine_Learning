# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split


import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# ## 1.	Apply the logistic regression method using the functions in the notebook «Logistic Regression as a Neural Network – BP alg.ipynb” to predict the biological response of a molecule
#
# > Data: bioresponse.csv
# > Description from Kaggle: “The data is in the comma separated values (CSV) format. Each row in this data set represents a molecule. The first column contains experimental data describing a real biological response; the molecule was seen to elicit this response (1), or not (0). The remaining columns represent molecular descriptors (d1 through d1776), these are caclulated properties that can capture some of the characteristics of the molecule - for example size, shape, or elemental constitution. The descriptor matrix has been normalized.”).
#
# Use 75% of the dataset to train the model, and the rest of the data to estimate its accuracy.

# %%
bio_df = pd.read_csv("/data/notebook_files/bioresponse.csv")
bio_df.columns
# Out:
# Index(['Activity', 'D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'D7', 'D8', 'D9',
#        ...
#        'D1767', 'D1768', 'D1769', 'D1770', 'D1771', 'D1772', 'D1773', 'D1774',
#        'D1775', 'D1776'],
#       dtype='object', length=1777)

# %%
X = np.array(bio_df.drop(columns=["Activity"]))
y = np.array(bio_df["Activity"])

print(f"X shape:\t{X.shape}\nY shape:\t{y.shape}")
# Out:
# X shape:	(3751, 1776)
# Y shape:	(3751,)

# %%
# Use 75% of the dataset to train the mode
calc_test_size = (100 - 75) / 100
calc_test_size
# Out:
# 0.25

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    test_size=calc_test_size, 
    random_state=42
)

# %%
print(f"X_train shape:\t{X_train.shape}\nY_train shape:\t{y_train.shape}")
print(f"X_test shape:\t{X_test.shape}\nY_test shape:\t{y_test.shape}")
# Out:
# X_train shape:	(2813, 1776)
# Y_train shape:	(2813,)
# X_test shape:	(938, 1776)
# Y_test shape:	(938,)

# %%
X_train = X_train.T
y_train = y_train.reshape((1, -1))

X_test = X_test.T
y_test = y_test.reshape((1, -1))

# %%
print(f"X_train shape:\t{X_train.shape}\nY_train shape:\t{y_train.shape}")
print(f"X_test shape:\t{X_test.shape}\nY_test shape:\t{y_test.shape}")
# Out:
# X_train shape:	(1776, 2813)
# Y_train shape:	(1, 2813)
# X_test shape:	(1776, 938)
# Y_test shape:	(1, 938)

# %%
# Functions from Logistic Regression as a Neural Network – BP alg.ipynb
def sigmoid(z):
    s = 1./(1.+np.exp(-z))
    
    return s


def initialize_with_zeros(dim):
    w = np.zeros((dim,1))
    b = 0.
    
    return w, b


def propagate(w, b, X, Y):
    m = X.shape[1]
    #print('number of objects = ',len(X))
    
    # FORWARD PROPAGATION (FROM X TO COST)
    A = sigmoid(np.dot(w.T,X)+b )                                 # compute activation
    cost = -(1./m)*np.sum(Y*np.log(A)+(1-Y)*np.log(1-A),axis=1)   # compute cost
    
    # BACKWARD PROPAGATION (TO FIND GRAD)
    dw = (1./m)*np.dot(X,(A-Y).T)
    db = (1./m)*np.sum(A-Y,axis=1)

    grads = {"dw": dw,
             "db": db}
    
    return grads, cost


def optimize(w, b, X, Y, num_iterations, learning_rate, print_cost = False):
    costs = []
    
    for i in range(num_iterations):
                
        # Cost and gradient calculation 
        grads, cost = propagate(w,b,X,Y)
        
        # Retrieve derivatives from grads
        dw = grads["dw"]
        db = grads["db"]
        
        # update rule
        w -=learning_rate*dw
        b -=learning_rate*db
        
        # Record the costs
        if i % 100 == 0:
            costs.append(cost[0])
        
        # Print the cost every 100 training iterations
        if print_cost and i % 100 == 0:
            print ("Cost after iteration %i: %f" %(i, cost[0]))
    
    params = {"w": w,
              "b": b}
    
    grads = {"dw": dw,
             "db": db}
    
    return params, grads, costs


def predict(w, b, X):
    m = X.shape[1]
    Y_prediction = np.zeros((1,m))
    w = w.reshape(X.shape[0], 1)
    
    # Compute vector "A" predicting the probabilities 
    A = sigmoid(np.dot(w.T,X)+b)
    
    for i in range(A.shape[1]):     
        # Convert probabilities A[0,i] to actual predictions p[0,i]
        if (A[0,i]<=0.5):
            Y_prediction[0][i]=0
        else:
            Y_prediction[0][i]=1
    
    return Y_prediction


def model(X_train, Y_train, X_test, Y_test, num_iterations = 2000, learning_rate = 0.5, print_cost = False, optimization_algorithm=optimize):   
    # initialize parameters with zeros 
    w, b = initialize_with_zeros(X_train.shape[0])

    # Gradient descent
    parameters, grads, costs = optimization_algorithm(w, b, X_train, Y_train, num_iterations, learning_rate, print_cost)
    
    # Retrieve parameters w and b from dictionary "parameters"
    w = parameters["w"]
    b = parameters["b"]
    
    # Predict test/train set examples
    Y_prediction_test = predict(w, b, X_test)
    Y_prediction_train = predict(w, b, X_train)

    # Print train/test Errors
    print("train accuracy: {} %".format(100 - np.mean(np.abs(Y_prediction_train - Y_train)) * 100))
    print("test accuracy: {} %".format(100 - np.mean(np.abs(Y_prediction_test - Y_test)) * 100))

    d = {"costs": costs,
         "Y_prediction_test": Y_prediction_test, 
         "Y_prediction_train" : Y_prediction_train, 
         "w" : w, 
         "b" : b,
         "learning_rate" : learning_rate,
         "num_iterations": num_iterations}
    
    return d

# %%
# From the Lecture
w, b, X, Y = np.array([[1.],[-1.]]),\
             4.,\
             np.array([[1.,5.,-1.],[10.,0.,-3.2]]),\
             np.array([[0,1,1]])

grads, cost = propagate(w, b, X, Y)
print ("dw = " + str(grads["dw"]))
print ("db = " + str(grads["db"]))
print ("cost = " + str(cost))
# Out:
# dw = [[0.0027004 ]
#  [0.02446984]]
# db = [0.00151471]
# cost = [0.00295537]

# %% [markdown]
# 2.	Modify `optimize()` function to implement the stochastic gradient descent (SGD) method and Adam optimization method using the numpy library. Apply them to solve the problem from p.1.

# %% [markdown]
# ### Stochastic Gradient Descent
#
# Stochastic gradient descent (SGD) performs a parameters (weights) update for each training example
# $(i)$ and label $y^{(i)}$:
#
# $θ_t := θ_{t − 1} − η∇_θ J (θ^{( i )}_{t − 1})$,
#
# where $J(θ)$ - objective (loss) function, $θ$ - model's parameters, $η$ - learning rate.

# %%
def SGD(w, b, X, Y, epochs, learning_rate=1e-1, print_cost=True):
    costs = []
    batch_size = 64   
    # batch_size = int(Y.shape[1] / 10)

    for epoch in range(epochs):
        for start in range(0, X.shape[1], batch_size):
            stop = start + batch_size
            
            X_batch = X[:, start:stop]
            y_batch = Y[:, start:stop]
        
            # Cost and gradient calculation 
            grads, cost = propagate(w,b,X_batch,y_batch)
            
            # Retrieve derivatives from grads
            dw = grads["dw"]
            db = grads["db"]
            
            # update rule
            w -= learning_rate*dw
            b -= learning_rate*db
            
            # Record the costs
            if epoch % 100 == 0:
                costs.append(cost)
            
            # Print the cost every 100 training iterations
            if print_cost and epochs % 100 == 0:
                print ("Cost after epoch %i: %f" %(epoch, cost))
    
    params = {
        "w": w,
        "b": b,
    }
    
    grads = {
        "dw": dw,
        "db": db,
    }
    
    return params, grads, costs

# %%
params, grads, costs = SGD(w, b, X, Y,
    epochs=5000,
    batch_size=1,
)

print("w = " + str(params["w"]))
print("b = " + str(params["b"]))
print("dw = " + str(grads["dw"]))
print("db = " + str(grads["db"]))
# Out:
# Cost after epoch 0: 0.000213
# Cost after epoch 0: 0.000213
# Cost after epoch 0: 0.000213
# Cost after epoch 1: 0.000213
# Cost after epoch 1: 0.000213
# Cost after epoch 1: 0.000213
# Cost after epoch 2: 0.000213
# Cost after epoch 2: 0.000213
# Cost after epoch 2: 0.000213
# Cost after epoch 3: 0.000213
# Cost after epoch 3: 0.000212
# Cost after epoch 3: 0.000212
# Cost after epoch 4: 0.000212
# Cost after epoch 4: 0.000212
# Cost after epoch 4: 0.000212
# Cost after epoch 5: 0.000212
# Cost after epoch 5: 0.000212
# Cost after epoch 5: 0.000212
# Cost after epoch 6: 0.000212
# Cost after epoch 6: 0.000212
# Cost after epoch 6: 0.000212
# Cost after epoch 7: 0.000212
# Cost after epoch 7: 0.000212
# Cost after epoch 7: 0.000212
# Cost after epoch 8: 0.000212
# Cost after epoch 8: 0.000212
# Cost after epoch 8: 0.000212
# Cost after epoch 9: 0.000212
# Cost after epoch 9: 0.000212
# Cost after epoch 9: 0.000212
# Cost after epoch 10: 0.000212
# Cost after epoch 10: 0.000212
# Cost after epoch 10: 0.000211
# Cost after epoch 11: 0.000211
# Cost after epoch 11: 0.000211
# Cost after epoch 11: 0.000211
# Cost after epoch 12: 0.000211
# Cost after epoch 12: 0.000211
# Cost after epoch 12: 0.000211
# Cost after epoch 13: 0.000211
# Cost after epoch 13: 0.000211
# Cost after epoch 13: 0.000211
# Cost after epoch 14: 0.000211
# Cost after epoch 14: 0.000211
# Cost after epoch 14: 0.000211
# Cost after epoch 15: 0.000211
# Cost after epoch 15: 0.000211
# Cost after epoch 15: 0.000211
# Cost after epoch 16: 0.000211
# Cost after epoch 16: 0.000211
# Cost after epoch 16: 0.000211
# Cost after epoch 17: 0.000211
# Cost after epoch 17: 0.000211
# Cost after epoch 17: 0.000210
# Cost after epoch 18: 0.000210
# Cost after epoch 18: 0.000210
# Cost after epoch 18: 0.000210
# Cost after epoch 19: 0.000210
# Cost after epoch 19: 0.000210
# Cost after epoch 19: 0.000210
# Cost after epoch 20: 0.000210
# Cost after epoch 20: 0.000210
# Cost after epoch 20: 0.000210
# Cost after epoch 21: 0.000210
# Cost after epoch 21: 0.000210
# Cost after epoch 21: 0.000210
# Cost after epoch 22: 0.000210
# Cost after epoch 22: 0.000210
# Cost after epoch 22: 0.000210
# Cost after epoch 23: 0.000210
# Cost after epoch 23: 0.000210
# Cost after epoch 23: 0.000210
# Cost after epoch 24: 0.000210
# Cost after epoch 24: 0.000210
# Cost after epoch 24: 0.000210
# Cost after epoch 25: 0.000209
# Cost after epoch 25: 0.000209
# Cost after epoch 25: 0.000209
# Cost after epoch 26: 0.000209
# Cost after epoch 26: 0.000209
# Cost after epoch 26: 0.000209
# Cost after epoch 27: 0.000209
# Cost after epoch 27: 0.000209
# Cost after epoch 27: 0.000209
# Cost after epoch 28: 0.000209
# Cost after epoch 28: 0.000209
# Cost after epoch 28: 0.000209
# Cost after epoch 29: 0.000209
# Cost after epoch 29: 0.000209
# Cost after epoch 29: 0.000209
# Cost after epoch 30: 0.000209
# Cost after epoch 30: 0.000209
# Cost after epoch 30: 0.000209
# Cost after epoch 31: 0.000209
# Cost after epoch 31: 0.000209
# Cost after epoch 31: 0.000209
# Cost after epoch 32: 0.000209
# Cost after epoch 32: 0.000208
# Cost after epoch 32: 0.000208
# Cost after epoch 33: 0.000208
# Cost after epoch 33: 0.000208
# Cost after epoch 33: 0.000208
# Cost after epoch 34: 0.000208
# Cost after epoch 34: 0.000208
# Cost after epoch 34: 0.000208
# Cost after epoch 35: 0.000208
# Cost after epoch 35: 0.000208
# Cost after epoch 35: 0.000208
# Cost after epoch 36: 0.000208
# Cost after epoch 36: 0.000208
# Cost after epoch 36: 0.000208
# Cost after epoch 37: 0.000208
# Cost after epoch 37: 0.000208
# Cost after epoch 37: 0.000208
# Cost after epoch 38: 0.000208
# Cost after epoch 38: 0.000208
# Cost after epoch 38: 0.000208
# Cost after epoch 39: 0.000208
# Cost after epoch 39: 0.000208
# Cost after epoch 39: 0.000208
# Cost after epoch 40: 0.000207
# Cost after epoch 40: 0.000207
# Cost after epoch 40: 0.000207
# Cost after epoch 41: 0.000207
# Cost after epoch 41: 0.000207
# Cost after epoch 41: 0.000207
# Cost after epoch 42: 0.000207
# Cost after epoch 42: 0.000207
# Cost after epoch 42: 0.000207
# Cost after epoch 43: 0.000207
# Cost after epoch 43: 0.000207
# Cost after epoch 43: 0.000207
# Cost after epoch 44: 0.000207
# Cost after epoch 44: 0.000207
# Cost after epoch 44: 0.000207
# Cost after epoch 45: 0.000207
# Cost after epoch 45: 0.000207
# Cost after epoch 45: 0.000207
# Cost after epoch 46: 0.000207
# Cost after epoch 46: 0.000207
# Cost after epoch 46: 0.000207
# Cost after epoch 47: 0.000207
# Cost after epoch 47: 0.000207
# Cost after epoch 47: 0.000206
# Cost after epoch 48: 0.000206
# Cost after epoch 48: 0.000206
# Cost after epoch 48: 0.000206
# Cost after epoch 49: 0.000206
# Cost after epoch 49: 0.000206
# Cost after epoch 49: 0.000206
# Cost after epoch 50: 0.000206
# Cost after epoch 50: 0.000206
# Cost after epoch 50: 0.000206
# Cost after epoch 51: 0.000206
# Cost after epoch 51: 0.000206
# Cost after epoch 51: 0.000206
# Cost after epoch 52: 0.000206
# Cost after epoch 52: 0.000206
# Cost after epoch 52: 0.000206
# Cost after epoch 53: 0.000206
# Cost after epoch 53: 0.000206
# Cost after epoch 53: 0.000206
# Cost after epoch 54: 0.000206
# Cost after epoch 54: 0.000206
# Cost after epoch 54: 0.000206
# Cost after epoch 55: 0.000206
# Cost after epoch 55: 0.000205
# Cost after epoch 55: 0.000205
# Cost after epoch 56: 0.000205
# Cost after epoch 56: 0.000205
# Cost after epoch 56: 0.000205
# Cost after epoch 57: 0.000205
# Cost after epoch 57: 0.000205
# Cost after epoch 57: 0.000205
# Cost after epoch 58: 0.000205
# Cost after epoch 58: 0.000205
# Cost after epoch 58: 0.000205
# Cost after epoch 59: 0.000205
# Cost after epoch 59: 0.000205
# Cost after epoch 59: 0.000205
# Cost after epoch 60: 0.000205
# Cost after epoch 60: 0.000205
# Cost after epoch 60: 0.000205
# Cost after epoch 61: 0.000205
# Cost after epoch 61: 0.000205
# Cost after epoch 61: 0.000205
# Cost after epoch 62: 0.000205
# Cost after epoch 62: 0.000205
# Cost after epoch 62: 0.000205
# Cost after epoch 63: 0.000204
# Cost after epoch 63: 0.000204
# Cost after epoch 63: 0.000204
# Cost after epoch 64: 0.000204
# Cost after epoch 64: 0.000204
# Cost after epoch 64: 0.000204
# Cost after epoch 65: 0.000204
# Cost after epoch 65: 0.000204
# Cost after epoch 65: 0.000204
# Cost after epoch 66: 0.000204
# Cost after epoch 66: 0.000204
# Cost after epoch 66: 0.000204
# Cost after epoch 67: 0.000204
# Cost after epoch 67: 0.000204
# Cost after epoch 67: 0.000204
# Cost after epoch 68: 0.000204
# Cost after epoch 68: 0.000204
# Cost after epoch 68: 0.000204
# Cost after epoch 69: 0.000204
# Cost after epoch 69: 0.000204
# Cost after epoch 69: 0.000204
# Cost after epoch 70: 0.000204
# Cost after epoch 70: 0.000204
# Cost after epoch 70: 0.000204
# Cost after epoch 71: 0.000203
# Cost after epoch 71: 0.000203
# Cost after epoch 71: 0.000203
# Cost after epoch 72: 0.000203
# Cost after epoch 72: 0.000203
# Cost after epoch 72: 0.000203
# Cost after epoch 73: 0.000203
# Cost after epoch 73: 0.000203
# Cost after epoch 73: 0.000203
# Cost after epoch 74: 0.000203
# Cost after epoch 74: 0.000203
# Cost after epoch 74: 0.000203
# Cost after epoch 75: 0.000203
# Cost after epoch 75: 0.000203
# Cost after epoch 75: 0.000203
# Cost after epoch 76: 0.000203
# Cost after epoch 76: 0.000203
# Cost after epoch 76: 0.000203
# Cost after epoch 77: 0.000203
# Cost after epoch 77: 0.000203
# Cost after epoch 77: 0.000203
# Cost after epoch 78: 0.000203
# Cost after epoch 78: 0.000203
# Cost after epoch 78: 0.000203
# Cost after epoch 79: 0.000202
# Cost after epoch 79: 0.000202
# Cost after epoch 79: 0.000202
# Cost after epoch 80: 0.000202
# Cost after epoch 80: 0.000202
# Cost after epoch 80: 0.000202
# Cost after epoch 81: 0.000202
# Cost after epoch 81: 0.000202
# Cost after epoch 81: 0.000202
# Cost after epoch 82: 0.000202
# Cost after epoch 82: 0.000202
# Cost after epoch 82: 0.000202
# Cost after epoch 83: 0.000202
# Cost after epoch 83: 0.000202
# Cost after epoch 83: 0.000202
# Cost after epoch 84: 0.000202
# Cost after epoch 84: 0.000202
# Cost after epoch 84: 0.000202
# Cost after epoch 85: 0.000202
# Cost after epoch 85: 0.000202
# Cost after epoch 85: 0.000202
# Cost after epoch 86: 0.000202
# Cost after epoch 86: 0.000202
# Cost after epoch 86: 0.000202
# Cost after epoch 87: 0.000202
# Cost after epoch 87: 0.000201
# Cost after epoch 87: 0.000201
# Cost after epoch 88: 0.000201
# Cost after epoch 88: 0.000201
# Cost after epoch 88: 0.000201
# Cost after epoch 89: 0.000201
# Cost after epoch 89: 0.000201
# Cost after epoch 89: 0.000201
# Cost after epoch 90: 0.000201
# Cost after epoch 90: 0.000201
# Cost after epoch 90: 0.000201
# Cost after epoch 91: 0.000201
# Cost after epoch 91: 0.000201
# Cost after epoch 91: 0.000201
# Cost after epoch 92: 0.000201
# Cost after epoch 92: 0.000201
# Cost after epoch 92: 0.000201
# Cost after epoch 93: 0.000201
# Cost after epoch 93: 0.000201
# Cost after epoch 93: 0.000201
# Cost after epoch 94: 0.000201
# Cost after epoch 94: 0.000201
# Cost after epoch 94: 0.000201
# Cost after epoch 95: 0.000201
# Cost after epoch 95: 0.000201
# Cost after epoch 95: 0.000200
# Cost after epoch 96: 0.000200
# Cost after epoch 96: 0.000200
# Cost after epoch 96: 0.000200
# Cost after epoch 97: 0.000200
# Cost after epoch 97: 0.000200
# Cost after epoch 97: 0.000200
# Cost after epoch 98: 0.000200
# Cost after epoch 98: 0.000200
# Cost after epoch 98: 0.000200
# Cost after epoch 99: 0.000200
# Cost after epoch 99: 0.000200
# Cost after epoch 99: 0.000200
# Cost after epoch 100: 0.000200
# Cost after epoch 100: 0.000200
# Cost after epoch 100: 0.000200
# Cost after epoch 101: 0.000200
# Cost after epoch 101: 0.000200
# Cost after epoch 101: 0.000200
# Cost after epoch 102: 0.000200
# Cost after epoch 102: 0.000200
# Cost after epoch 102: 0.000200
# Cost after epoch 103: 0.000200
# Cost after epoch 103: 0.000200
# Cost after epoch 103: 0.000200
# Cost after epoch 104: 0.000199
# Cost after epoch 104: 0.000199
# Cost after epoch 104: 0.000199
# Cost after epoch 105: 0.000199
# Cost after epoch 105: 0.000199
# Cost after epoch 105: 0.000199
# Cost after epoch 106: 0.000199
# Cost after epoch 106: 0.000199
# Cost after epoch 106: 0.000199
# Cost after epoch 107: 0.000199
# Cost after epoch 107: 0.000199
# Cost after epoch 107: 0.000199
# Cost after epoch 108: 0.000199
# Cost after epoch 108: 0.000199
# Cost after epoch 108: 0.000199
# Cost after epoch 109: 0.000199
# Cost after epoch 109: 0.000199
# Cost after epoch 109: 0.000199
# Cost after epoch 110: 0.000199
# Cost after epoch 110: 0.000199
# Cost after epoch 110: 0.000199
# Cost after epoch 111: 0.000199
# Cost after epoch 111: 0.000199
# Cost after epoch 111: 0.000199
# Cost after epoch 112: 0.000199
# Cost after epoch 112: 0.000198
# Cost after epoch 112: 0.000198
# Cost after epoch 113: 0.000198
# Cost after epoch 113: 0.000198
# Cost after epoch 113: 0.000198
# Cost after epoch 114: 0.000198
# Cost after epoch 114: 0.000198
# Cost after epoch 114: 0.000198
# Cost after epoch 115: 0.000198
# Cost after epoch 115: 0.000198
# Cost after epoch 115: 0.000198
# Cost after epoch 116: 0.000198
# Cost after epoch 116: 0.000198
# Cost after epoch 116: 0.000198
# Cost after epoch 117: 0.000198
# Cost after epoch 117: 0.000198
# Cost after epoch 117: 0.000198
# Cost after epoch 118: 0.000198
# Cost after epoch 118: 0.000198
# Cost after epoch 118: 0.000198
# Cost after epoch 119: 0.000198
# Cost after epoch 119: 0.000198
# Cost after epoch 119: 0.000198
# Cost after epoch 120: 0.000198
# Cost after epoch 120: 0.000198
# Cost after epoch 120: 0.000198
# Cost after epoch 121: 0.000197
# Cost after epoch 121: 0.000197
# Cost after epoch 121: 0.000197
# Cost after epoch 122: 0.000197
# Cost after epoch 122: 0.000197
# Cost after epoch 122: 0.000197
# Cost after epoch 123: 0.000197
# Cost after epoch 123: 0.000197
# Cost after epoch 123: 0.000197
# Cost after epoch 124: 0.000197
# Cost after epoch 124: 0.000197
# Cost after epoch 124: 0.000197
# Cost after epoch 125: 0.000197
# Cost after epoch 125: 0.000197
# Cost after epoch 125: 0.000197
# Cost after epoch 126: 0.000197
# Cost after epoch 126: 0.000197
# Cost after epoch 126: 0.000197
# Cost after epoch 127: 0.000197
# Cost after epoch 127: 0.000197
# Cost after epoch 127: 0.000197
# Cost after epoch 128: 0.000197
# Cost after epoch 128: 0.000197
# Cost after epoch 128: 0.000197
# Cost after epoch 129: 0.000197
# Cost after epoch 129: 0.000197
# Cost after epoch 129: 0.000196
# Cost after epoch 130: 0.000196
# Cost after epoch 130: 0.000196
# Cost after epoch 130: 0.000196
# Cost after epoch 131: 0.000196
# Cost after epoch 131: 0.000196
# Cost after epoch 131: 0.000196
# Cost after epoch 132: 0.000196
# Cost after epoch 132: 0.000196
# Cost after epoch 132: 0.000196
# Cost after epoch 133: 0.000196
# Cost after epoch 133: 0.000196
# Cost after epoch 133: 0.000196
# Cost after epoch 134: 0.000196
# Cost after epoch 134: 0.000196
# Cost after epoch 134: 0.000196
# Cost after epoch 135: 0.000196
# Cost after epoch 135: 0.000196
# Cost after epoch 135: 0.000196
# Cost after epoch 136: 0.000196
# Cost after epoch 136: 0.000196
# Cost after epoch 136: 0.000196
# Cost after epoch 137: 0.000196
# Cost after epoch 137: 0.000196
# Cost after epoch 137: 0.000196
# Cost after epoch 138: 0.000196
# Cost after epoch 138: 0.000196
# Cost after epoch 138: 0.000195
# Cost after epoch 139: 0.000195
# Cost after epoch 139: 0.000195
# Cost after epoch 139: 0.000195
# Cost after epoch 140: 0.000195
# Cost after epoch 140: 0.000195
# Cost after epoch 140: 0.000195
# Cost after epoch 141: 0.000195
# Cost after epoch 141: 0.000195
# Cost after epoch 141: 0.000195
# Cost after epoch 142: 0.000195
# Cost after epoch 142: 0.000195
# Cost after epoch 142: 0.000195
# Cost after epoch 143: 0.000195
# Cost after epoch 143: 0.000195
# Cost after epoch 143: 0.000195
# Cost after epoch 144: 0.000195
# Cost after epoch 144: 0.000195
# Cost after epoch 144: 0.000195
# Cost after epoch 145: 0.000195
# Cost after epoch 145: 0.000195
# Cost after epoch 145: 0.000195
# Cost after epoch 146: 0.000195
# Cost after epoch 146: 0.000195
# Cost after epoch 146: 0.000195
# Cost after epoch 147: 0.000195
# Cost after epoch 147: 0.000195
# Cost after epoch 147: 0.000194
# Cost after epoch 148: 0.000194
# Cost after epoch 148: 0.000194
# Cost after epoch 148: 0.000194
# Cost after epoch 149: 0.000194
# Cost after epoch 149: 0.000194
# Cost after epoch 149: 0.000194
# Cost after epoch 150: 0.000194
# Cost after epoch 150: 0.000194
# Cost after epoch 150: 0.000194
# Cost after epoch 151: 0.000194
# Cost after epoch 151: 0.000194
# Cost after epoch 151: 0.000194
# Cost after epoch 152: 0.000194
# Cost after epoch 152: 0.000194
# Cost after epoch 152: 0.000194
# Cost after epoch 153: 0.000194
# Cost after epoch 153: 0.000194
# Cost after epoch 153: 0.000194
# Cost after epoch 154: 0.000194
# Cost after epoch 154: 0.000194
# Cost after epoch 154: 0.000194
# Cost after epoch 155: 0.000194
# Cost after epoch 155: 0.000194
# Cost after epoch 155: 0.000194
# Cost after epoch 156: 0.000194
# Cost after epoch 156: 0.000194
# Cost after epoch 156: 0.000194
# Cost after epoch 157: 0.000193
# Cost after epoch 157: 0.000193
# Cost after epoch 157: 0.000193
# Cost after epoch 158: 0.000193
# Cost after epoch 158: 0.000193
# Cost after epoch 158: 0.000193
# Cost after epoch 159: 0.000193
# Cost after epoch 159: 0.000193
# Cost after epoch 159: 0.000193
# Cost after epoch 160: 0.000193
# Cost after epoch 160: 0.000193
# Cost after epoch 160: 0.000193
# Cost after epoch 161: 0.000193
# Cost after epoch 161: 0.000193
# Cost after epoch 161: 0.000193
# Cost after epoch 162: 0.000193
# Cost after epoch 162: 0.000193
# Cost after epoch 162: 0.000193
# Cost after epoch 163: 0.000193
# Cost after epoch 163: 0.000193
# Cost after epoch 163: 0.000193
# Cost after epoch 164: 0.000193
# Cost after epoch 164: 0.000193
# Cost after epoch 164: 0.000193
# Cost after epoch 165: 0.000193
# Cost after epoch 165: 0.000193
# Cost after epoch 165: 0.000193
# Cost after epoch 166: 0.000192
# Cost after epoch 166: 0.000192
# Cost after epoch 166: 0.000192
# Cost after epoch 167: 0.000192
# Cost after epoch 167: 0.000192
# Cost after epoch 167: 0.000192
# Cost after epoch 168: 0.000192
# Cost after epoch 168: 0.000192
# Cost after epoch 168: 0.000192
# Cost after epoch 169: 0.000192
# Cost after epoch 169: 0.000192
# Cost after epoch 169: 0.000192
# Cost after epoch 170: 0.000192
# Cost after epoch 170: 0.000192
# Cost after epoch 170: 0.000192
# Cost after epoch 171: 0.000192
# Cost after epoch 171: 0.000192
# Cost after epoch 171: 0.000192
# Cost after epoch 172: 0.000192
# Cost after epoch 172: 0.000192
# Cost after epoch 172: 0.000192
# Cost after epoch 173: 0.000192
# Cost after epoch 173: 0.000192
# Cost after epoch 173: 0.000192
# Cost after epoch 174: 0.000192
# Cost after epoch 174: 0.000192
# Cost after epoch 174: 0.000192
# Cost after epoch 175: 0.000192
# Cost after epoch 175: 0.000192
# Cost after epoch 175: 0.000191
# Cost after epoch 176: 0.000191
# Cost after epoch 176: 0.000191
# Cost after epoch 176: 0.000191
# Cost after epoch 177: 0.000191
# Cost after epoch 177: 0.000191
# Cost after epoch 177: 0.000191
# Cost after epoch 178: 0.000191
# Cost after epoch 178: 0.000191
# Cost after epoch 178: 0.000191
# Cost after epoch 179: 0.000191
# Cost after epoch 179: 0.000191
# Cost after epoch 179: 0.000191
# Cost after epoch 180: 0.000191
# Cost after epoch 180: 0.000191
# Cost after epoch 180: 0.000191
# Cost after epoch 181: 0.000191
# Cost after epoch 181: 0.000191
# Cost after epoch 181: 0.000191
# Cost after epoch 182: 0.000191
# Cost after epoch 182: 0.000191
# Cost after epoch 182: 0.000191
# Cost after epoch 183: 0.000191
# Cost after epoch 183: 0.000191
# Cost after epoch 183: 0.000191
# Cost after epoch 184: 0.000191
# Cost after epoch 184: 0.000191
# Cost after epoch 184: 0.000191
# Cost after epoch 185: 0.000190
# Cost after epoch 185: 0.000190
# Cost after epoch 185: 0.000190
# Cost after epoch 186: 0.000190
# Cost after epoch 186: 0.000190
# Cost after epoch 186: 0.000190
# Cost after epoch 187: 0.000190
# Cost after epoch 187: 0.000190
# Cost after epoch 187: 0.000190
# Cost after epoch 188: 0.000190
# Cost after epoch 188: 0.000190
# Cost after epoch 188: 0.000190
# Cost after epoch 189: 0.000190
# Cost after epoch 189: 0.000190
# Cost after epoch 189: 0.000190
# Cost after epoch 190: 0.000190
# Cost after epoch 190: 0.000190
# Cost after epoch 190: 0.000190
# Cost after epoch 191: 0.000190
# Cost after epoch 191: 0.000190
# Cost after epoch 191: 0.000190
# Cost after epoch 192: 0.000190
# Cost after epoch 192: 0.000190
# Cost after epoch 192: 0.000190
# Cost after epoch 193: 0.000190
# Cost after epoch 193: 0.000190
# Cost after epoch 193: 0.000190
# Cost after epoch 194: 0.000190
# Cost after epoch 194: 0.000190
# Cost after epoch 194: 0.000189
# Cost after epoch 195: 0.000189
# Cost after epoch 195: 0.000189
# Cost after epoch 195: 0.000189
# Cost after epoch 196: 0.000189
# Cost after epoch 196: 0.000189
# Cost after epoch 196: 0.000189
# Cost after epoch 197: 0.000189
# Cost after epoch 197: 0.000189
# Cost after epoch 197: 0.000189
# Cost after epoch 198: 0.000189
# Cost after epoch 198: 0.000189
# Cost after epoch 198: 0.000189
# Cost after epoch 199: 0.000189
# Cost after epoch 199: 0.000189
# Cost after epoch 199: 0.000189
# Cost after epoch 200: 0.000189
# Cost after epoch 200: 0.000189
# Cost after epoch 200: 0.000189
# Cost after epoch 201: 0.000189
# Cost after epoch 201: 0.000189
# Cost after epoch 201: 0.000189
# Cost after epoch 202: 0.000189
# Cost after epoch 202: 0.000189
# Cost after epoch 202: 0.000189
# Cost after epoch 203: 0.000189
# Cost after epoch 203: 0.000189
# Cost after epoch 203: 0.000189
# Cost after epoch 204: 0.000189
# Cost after epoch 204: 0.000189
# Cost after epoch 204: 0.000188
# Cost after epoch 205: 0.000188
# Cost after epoch 205: 0.000188
# Cost after epoch 205: 0.000188
# Cost after epoch 206: 0.000188
# Cost after epoch 206: 0.000188
# Cost after epoch 206: 0.000188
# Cost after epoch 207: 0.000188
# Cost after epoch 207: 0.000188
# Cost after epoch 207: 0.000188
# Cost after epoch 208: 0.000188
# Cost after epoch 208: 0.000188
# Cost after epoch 208: 0.000188
# Cost after epoch 209: 0.000188
# Cost after epoch 209: 0.000188
# Cost after epoch 209: 0.000188
# Cost after epoch 210: 0.000188
# Cost after epoch 210: 0.000188
# Cost after epoch 210: 0.000188
# Cost after epoch 211: 0.000188
# Cost after epoch 211: 0.000188
# Cost after epoch 211: 0.000188
# Cost after epoch 212: 0.000188
# Cost after epoch 212: 0.000188
# Cost after epoch 212: 0.000188
# Cost after epoch 213: 0.000188
# Cost after epoch 213: 0.000188
# Cost after epoch 213: 0.000188
# Cost after epoch 214: 0.000188
# Cost after epoch 214: 0.000188
# Cost after epoch 214: 0.000187
# Cost after epoch 215: 0.000187
# Cost after epoch 215: 0.000187
# Cost after epoch 215: 0.000187
# Cost after epoch 216: 0.000187
# Cost after epoch 216: 0.000187
# Cost after epoch 216: 0.000187
# Cost after epoch 217: 0.000187
# Cost after epoch 217: 0.000187
# Cost after epoch 217: 0.000187
# Cost after epoch 218: 0.000187
# Cost after epoch 218: 0.000187
# Cost after epoch 218: 0.000187
# Cost after epoch 219: 0.000187
# Cost after epoch 219: 0.000187
# Cost after epoch 219: 0.000187
# Cost after epoch 220: 0.000187
# Cost after epoch 220: 0.000187
# Cost after epoch 220: 0.000187
# Cost after epoch 221: 0.000187
# Cost after epoch 221: 0.000187
# Cost after epoch 221: 0.000187
# Cost after epoch 222: 0.000187
# Cost after epoch 222: 0.000187
# Cost after epoch 222: 0.000187
# Cost after epoch 223: 0.000187
# Cost after epoch 223: 0.000187
# Cost after epoch 223: 0.000187
# Cost after epoch 224: 0.000187
# Cost after epoch 224: 0.000187
# Cost after epoch 224: 0.000186
# Cost after epoch 225: 0.000186
# Cost after epoch 225: 0.000186
# Cost after epoch 225: 0.000186
# Cost after epoch 226: 0.000186
# Cost after epoch 226: 0.000186
# Cost after epoch 226: 0.000186
# Cost after epoch 227: 0.000186
# Cost after epoch 227: 0.000186
# Cost after epoch 227: 0.000186
# Cost after epoch 228: 0.000186
# Cost after epoch 228: 0.000186
# Cost after epoch 228: 0.000186
# Cost after epoch 229: 0.000186
# Cost after epoch 229: 0.000186
# Cost after epoch 229: 0.000186
# Cost after epoch 230: 0.000186
# Cost after epoch 230: 0.000186
# Cost after epoch 230: 0.000186
# Cost after epoch 231: 0.000186
# Cost after epoch 231: 0.000186
# Cost after epoch 231: 0.000186
# Cost after epoch 232: 0.000186
# Cost after epoch 232: 0.000186
# Cost after epoch 232: 0.000186
# Cost after epoch 233: 0.000186
# Cost after epoch 233: 0.000186
# Cost after epoch 233: 0.000186
# Cost after epoch 234: 0.000186
# Cost after epoch 234: 0.000186
# Cost after epoch 234: 0.000186
# Cost after epoch 235: 0.000185
# Cost after epoch 235: 0.000185
# Cost after epoch 235: 0.000185
# Cost after epoch 236: 0.000185
# Cost after epoch 236: 0.000185
# Cost after epoch 236: 0.000185
# Cost after epoch 237: 0.000185
# Cost after epoch 237: 0.000185
# Cost after epoch 237: 0.000185
# Cost after epoch 238: 0.000185
# Cost after epoch 238: 0.000185
# Cost after epoch 238: 0.000185
# Cost after epoch 239: 0.000185
# Cost after epoch 239: 0.000185
# Cost after epoch 239: 0.000185
# Cost after epoch 240: 0.000185
# Cost after epoch 240: 0.000185
# Cost after epoch 240: 0.000185
# Cost after epoch 241: 0.000185
# Cost after epoch 241: 0.000185
# Cost after epoch 241: 0.000185
# Cost after epoch 242: 0.000185
# Cost after epoch 242: 0.000185
# Cost after epoch 242: 0.000185
# Cost after epoch 243: 0.000185
# Cost after epoch 243: 0.000185
# Cost after epoch 243: 0.000185
# Cost after epoch 244: 0.000185
# Cost after epoch 244: 0.000185
# Cost after epoch 244: 0.000185
# Cost after epoch 245: 0.000185
# Cost after epoch 245: 0.000184
# Cost after epoch 245: 0.000184
# Cost after epoch 246: 0.000184
# Cost after epoch 246: 0.000184
# Cost after epoch 246: 0.000184
# Cost after epoch 247: 0.000184
# Cost after epoch 247: 0.000184
# Cost after epoch 247: 0.000184
# Cost after epoch 248: 0.000184
# Cost after epoch 248: 0.000184
# Cost after epoch 248: 0.000184
# Cost after epoch 249: 0.000184
# Cost after epoch 249: 0.000184
# Cost after epoch 249: 0.000184
# Cost after epoch 250: 0.000184
# Cost after epoch 250: 0.000184
# Cost after epoch 250: 0.000184
# Cost after epoch 251: 0.000184
# Cost after epoch 251: 0.000184
# Cost after epoch 251: 0.000184
# Cost after epoch 252: 0.000184
# Cost after epoch 252: 0.000184
# Cost after epoch 252: 0.000184
# Cost after epoch 253: 0.000184
# Cost after epoch 253: 0.000184
# Cost after epoch 253: 0.000184
# Cost after epoch 254: 0.000184
# Cost after epoch 254: 0.000184
# Cost after epoch 254: 0.000184
# Cost after epoch 255: 0.000184
# Cost after epoch 255: 0.000184
# Cost after epoch 255: 0.000184
# Cost after epoch 256: 0.000183
# Cost after epoch 256: 0.000183
# Cost after epoch 256: 0.000183
# Cost after epoch 257: 0.000183
# Cost after epoch 257: 0.000183
# Cost after epoch 257: 0.000183
# Cost after epoch 258: 0.000183
# Cost after epoch 258: 0.000183
# Cost after epoch 258: 0.000183
# Cost after epoch 259: 0.000183
# Cost after epoch 259: 0.000183
# Cost after epoch 259: 0.000183
# Cost after epoch 260: 0.000183
# Cost after epoch 260: 0.000183
# Cost after epoch 260: 0.000183
# Cost after epoch 261: 0.000183
# Cost after epoch 261: 0.000183
# Cost after epoch 261: 0.000183
# Cost after epoch 262: 0.000183
# Cost after epoch 262: 0.000183
# Cost after epoch 262: 0.000183
# Cost after epoch 263: 0.000183
# Cost after epoch 263: 0.000183
# Cost after epoch 263: 0.000183
# Cost after epoch 264: 0.000183
# Cost after epoch 264: 0.000183
# Cost after epoch 264: 0.000183
# Cost after epoch 265: 0.000183
# Cost after epoch 265: 0.000183
# Cost after epoch 265: 0.000183
# Cost after epoch 266: 0.000183
# Cost after epoch 266: 0.000183
# Cost after epoch 266: 0.000182
# Cost after epoch 267: 0.000182
# Cost after epoch 267: 0.000182
# Cost after epoch 267: 0.000182
# Cost after epoch 268: 0.000182
# Cost after epoch 268: 0.000182
# Cost after epoch 268: 0.000182
# Cost after epoch 269: 0.000182
# Cost after epoch 269: 0.000182
# Cost after epoch 269: 0.000182
# Cost after epoch 270: 0.000182
# Cost after epoch 270: 0.000182
# Cost after epoch 270: 0.000182
# Cost after epoch 271: 0.000182
# Cost after epoch 271: 0.000182
# Cost after epoch 271: 0.000182
# Cost after epoch 272: 0.000182
# Cost after epoch 272: 0.000182
# Cost after epoch 272: 0.000182
# Cost after epoch 273: 0.000182
# Cost after epoch 273: 0.000182
# Cost after epoch 273: 0.000182
# Cost after epoch 274: 0.000182
# Cost after epoch 274: 0.000182
# Cost after epoch 274: 0.000182
# Cost after epoch 275: 0.000182
# Cost after epoch 275: 0.000182
# Cost after epoch 275: 0.000182
# Cost after epoch 276: 0.000182
# Cost after epoch 276: 0.000182
# Cost after epoch 276: 0.000182
# Cost after epoch 277: 0.000182
# Cost after epoch 277: 0.000182
# Cost after epoch 277: 0.000181
# Cost after epoch 278: 0.000181
# Cost after epoch 278: 0.000181
# Cost after epoch 278: 0.000181
# Cost after epoch 279: 0.000181
# Cost after epoch 279: 0.000181
# Cost after epoch 279: 0.000181
# Cost after epoch 280: 0.000181
# Cost after epoch 280: 0.000181
# Cost after epoch 280: 0.000181
# Cost after epoch 281: 0.000181
# Cost after epoch 281: 0.000181
# Cost after epoch 281: 0.000181
# Cost after epoch 282: 0.000181
# Cost after epoch 282: 0.000181
# Cost after epoch 282: 0.000181
# Cost after epoch 283: 0.000181
# Cost after epoch 283: 0.000181
# Cost after epoch 283: 0.000181
# Cost after epoch 284: 0.000181
# Cost after epoch 284: 0.000181
# Cost after epoch 284: 0.000181
# Cost after epoch 285: 0.000181
# Cost after epoch 285: 0.000181
# Cost after epoch 285: 0.000181
# Cost after epoch 286: 0.000181
# Cost after epoch 286: 0.000181
# Cost after epoch 286: 0.000181
# Cost after epoch 287: 0.000181
# Cost after epoch 287: 0.000181
# Cost after epoch 287: 0.000181
# Cost after epoch 288: 0.000181
# Cost after epoch 288: 0.000181
# Cost after epoch 288: 0.000180
# Cost after epoch 289: 0.000180
# Cost after epoch 289: 0.000180
# Cost after epoch 289: 0.000180
# Cost after epoch 290: 0.000180
# Cost after epoch 290: 0.000180
# Cost after epoch 290: 0.000180
# Cost after epoch 291: 0.000180
# Cost after epoch 291: 0.000180
# Cost after epoch 291: 0.000180
# Cost after epoch 292: 0.000180
# Cost after epoch 292: 0.000180
# Cost after epoch 292: 0.000180
# Cost after epoch 293: 0.000180
# Cost after epoch 293: 0.000180
# Cost after epoch 293: 0.000180
# Cost after epoch 294: 0.000180
# Cost after epoch 294: 0.000180
# Cost after epoch 294: 0.000180
# Cost after epoch 295: 0.000180
# Cost after epoch 295: 0.000180
# Cost after epoch 295: 0.000180
# Cost after epoch 296: 0.000180
# Cost after epoch 296: 0.000180
# Cost after epoch 296: 0.000180
# Cost after epoch 297: 0.000180
# Cost after epoch 297: 0.000180
# Cost after epoch 297: 0.000180
# Cost after epoch 298: 0.000180
# Cost after epoch 298: 0.000180
# Cost after epoch 298: 0.000180
# Cost after epoch 299: 0.000180
# Cost after epoch 299: 0.000180
# Cost after epoch 299: 0.000180
# Cost after epoch 300: 0.000179
# Cost after epoch 300: 0.000179
# Cost after epoch 300: 0.000179
# Cost after epoch 301: 0.000179
# Cost after epoch 301: 0.000179
# Cost after epoch 301: 0.000179
# Cost after epoch 302: 0.000179
# Cost after epoch 302: 0.000179
# Cost after epoch 302: 0.000179
# Cost after epoch 303: 0.000179
# Cost after epoch 303: 0.000179
# Cost after epoch 303: 0.000179
# Cost after epoch 304: 0.000179
# Cost after epoch 304: 0.000179
# Cost after epoch 304: 0.000179
# Cost after epoch 305: 0.000179
# Cost after epoch 305: 0.000179
# Cost after epoch 305: 0.000179
# Cost after epoch 306: 0.000179
# Cost after epoch 306: 0.000179
# Cost after epoch 306: 0.000179
# Cost after epoch 307: 0.000179
# Cost after epoch 307: 0.000179
# Cost after epoch 307: 0.000179
# Cost after epoch 308: 0.000179
# Cost after epoch 308: 0.000179
# Cost after epoch 308: 0.000179
# Cost after epoch 309: 0.000179
# Cost after epoch 309: 0.000179
# Cost after epoch 309: 0.000179
# Cost after epoch 310: 0.000179
# Cost after epoch 310: 0.000179
# Cost after epoch 310: 0.000179
# Cost after epoch 311: 0.000179
# Cost after epoch 311: 0.000178
# Cost after epoch 311: 0.000178
# Cost after epoch 312: 0.000178
# Cost after epoch 312: 0.000178
# Cost after epoch 312: 0.000178
# Cost after epoch 313: 0.000178
# Cost after epoch 313: 0.000178
# Cost after epoch 313: 0.000178
# Cost after epoch 314: 0.000178
# Cost after epoch 314: 0.000178
# Cost after epoch 314: 0.000178
# Cost after epoch 315: 0.000178
# Cost after epoch 315: 0.000178
# Cost after epoch 315: 0.000178
# Cost after epoch 316: 0.000178
# Cost after epoch 316: 0.000178
# Cost after epoch 316: 0.000178
# Cost after epoch 317: 0.000178
# Cost after epoch 317: 0.000178
# Cost after epoch 317: 0.000178
# Cost after epoch 318: 0.000178
# Cost after epoch 318: 0.000178
# Cost after epoch 318: 0.000178
# Cost after epoch 319: 0.000178
# Cost after epoch 319: 0.000178
# Cost after epoch 319: 0.000178
# Cost after epoch 320: 0.000178
# Cost after epoch 320: 0.000178
# Cost after epoch 320: 0.000178
# Cost after epoch 321: 0.000178
# Cost after epoch 321: 0.000178
# Cost after epoch 321: 0.000178
# Cost after epoch 322: 0.000178
# Cost after epoch 322: 0.000178
# Cost after epoch 322: 0.000178
# Cost after epoch 323: 0.000177
# Cost after epoch 323: 0.000177
# Cost after epoch 323: 0.000177
# Cost after epoch 324: 0.000177
# Cost after epoch 324: 0.000177
# Cost after epoch 324: 0.000177
# Cost after epoch 325: 0.000177
# Cost after epoch 325: 0.000177
# Cost after epoch 325: 0.000177
# Cost after epoch 326: 0.000177
# Cost after epoch 326: 0.000177
# Cost after epoch 326: 0.000177
# Cost after epoch 327: 0.000177
# Cost after epoch 327: 0.000177
# Cost after epoch 327: 0.000177
# Cost after epoch 328: 0.000177
# Cost after epoch 328: 0.000177
# Cost after epoch 328: 0.000177
# Cost after epoch 329: 0.000177
# Cost after epoch 329: 0.000177
# Cost after epoch 329: 0.000177
# Cost after epoch 330: 0.000177
# Cost after epoch 330: 0.000177
# Cost after epoch 330: 0.000177
# Cost after epoch 331: 0.000177
# Cost after epoch 331: 0.000177
# Cost after epoch 331: 0.000177
# Cost after epoch 332: 0.000177
# Cost after epoch 332: 0.000177
# Cost after epoch 332: 0.000177
# Cost after epoch 333: 0.000177
# Cost after epoch 333: 0.000177
# Cost after epoch 333: 0.000177
# Cost after epoch 334: 0.000177
# Cost after epoch 334: 0.000177
# Cost after epoch 334: 0.000176
# Cost after epoch 335: 0.000176
# Cost after epoch 335: 0.000176
# Cost after epoch 335: 0.000176
# Cost after epoch 336: 0.000176
# Cost after epoch 336: 0.000176
# Cost after epoch 336: 0.000176
# Cost after epoch 337: 0.000176
# Cost after epoch 337: 0.000176
# Cost after epoch 337: 0.000176
# Cost after epoch 338: 0.000176
# Cost after epoch 338: 0.000176
# Cost after epoch 338: 0.000176
# Cost after epoch 339: 0.000176
# Cost after epoch 339: 0.000176
# Cost after epoch 339: 0.000176
# Cost after epoch 340: 0.000176
# Cost after epoch 340: 0.000176
# Cost after epoch 340: 0.000176
# Cost after epoch 341: 0.000176
# Cost after epoch 341: 0.000176
# Cost after epoch 341: 0.000176
# Cost after epoch 342: 0.000176
# Cost after epoch 342: 0.000176
# Cost after epoch 342: 0.000176
# Cost after epoch 343: 0.000176
# Cost after epoch 343: 0.000176
# Cost after epoch 343: 0.000176
# Cost after epoch 344: 0.000176
# Cost after epoch 344: 0.000176
# Cost after epoch 344: 0.000176
# Cost after epoch 345: 0.000176
# Cost after epoch 345: 0.000176
# Cost after epoch 345: 0.000176
# Cost after epoch 346: 0.000176
# Cost after epoch 346: 0.000176
# Cost after epoch 346: 0.000175
# Cost after epoch 347: 0.000175
# Cost after epoch 347: 0.000175
# Cost after epoch 347: 0.000175
# Cost after epoch 348: 0.000175
# Cost after epoch 348: 0.000175
# Cost after epoch 348: 0.000175
# Cost after epoch 349: 0.000175
# Cost after epoch 349: 0.000175
# Cost after epoch 349: 0.000175
# Cost after epoch 350: 0.000175
# Cost after epoch 350: 0.000175
# Cost after epoch 350: 0.000175
# Cost after epoch 351: 0.000175
# Cost after epoch 351: 0.000175
# Cost after epoch 351: 0.000175
# Cost after epoch 352: 0.000175
# Cost after epoch 352: 0.000175
# Cost after epoch 352: 0.000175
# Cost after epoch 353: 0.000175
# Cost after epoch 353: 0.000175
# Cost after epoch 353: 0.000175
# Cost after epoch 354: 0.000175
# Cost after epoch 354: 0.000175
# Cost after epoch 354: 0.000175
# Cost after epoch 355: 0.000175
# Cost after epoch 355: 0.000175
# Cost after epoch 355: 0.000175
# Cost after epoch 356: 0.000175
# Cost after epoch 356: 0.000175
# Cost after epoch 356: 0.000175
# Cost after epoch 357: 0.000175
# Cost after epoch 357: 0.000175
# Cost after epoch 357: 0.000175
# Cost after epoch 358: 0.000175
# Cost after epoch 358: 0.000175
# Cost after epoch 358: 0.000175
# Cost after epoch 359: 0.000174
# Cost after epoch 359: 0.000174
# Cost after epoch 359: 0.000174
# Cost after epoch 360: 0.000174
# Cost after epoch 360: 0.000174
# Cost after epoch 360: 0.000174
# Cost after epoch 361: 0.000174
# Cost after epoch 361: 0.000174
# Cost after epoch 361: 0.000174
# Cost after epoch 362: 0.000174
# Cost after epoch 362: 0.000174
# Cost after epoch 362: 0.000174
# Cost after epoch 363: 0.000174
# Cost after epoch 363: 0.000174
# Cost after epoch 363: 0.000174
# Cost after epoch 364: 0.000174
# Cost after epoch 364: 0.000174
# Cost after epoch 364: 0.000174
# Cost after epoch 365: 0.000174
# Cost after epoch 365: 0.000174
# Cost after epoch 365: 0.000174
# Cost after epoch 366: 0.000174
# Cost after epoch 366: 0.000174
# Cost after epoch 366: 0.000174
# Cost after epoch 367: 0.000174
# Cost after epoch 367: 0.000174
# Cost after epoch 367: 0.000174
# Cost after epoch 368: 0.000174
# Cost after epoch 368: 0.000174
# Cost after epoch 368: 0.000174
# Cost after epoch 369: 0.000174
# Cost after epoch 369: 0.000174
# Cost after epoch 369: 0.000174
# Cost after epoch 370: 0.000174
# Cost after epoch 370: 0.000174
# Cost after epoch 370: 0.000174
# Cost after epoch 371: 0.000174
# Cost after epoch 371: 0.000173
# Cost after epoch 371: 0.000173
# Cost after epoch 372: 0.000173
# Cost after epoch 372: 0.000173
# Cost after epoch 372: 0.000173
# Cost after epoch 373: 0.000173
# Cost after epoch 373: 0.000173
# Cost after epoch 373: 0.000173
# Cost after epoch 374: 0.000173
# Cost after epoch 374: 0.000173
# Cost after epoch 374: 0.000173
# Cost after epoch 375: 0.000173
# Cost after epoch 375: 0.000173
# Cost after epoch 375: 0.000173
# Cost after epoch 376: 0.000173
# Cost after epoch 376: 0.000173
# Cost after epoch 376: 0.000173
# Cost after epoch 377: 0.000173
# Cost after epoch 377: 0.000173
# Cost after epoch 377: 0.000173
# Cost after epoch 378: 0.000173
# Cost after epoch 378: 0.000173
# Cost after epoch 378: 0.000173
# Cost after epoch 379: 0.000173
# Cost after epoch 379: 0.000173
# Cost after epoch 379: 0.000173
# Cost after epoch 380: 0.000173
# Cost after epoch 380: 0.000173
# Cost after epoch 380: 0.000173
# Cost after epoch 381: 0.000173
# Cost after epoch 381: 0.000173
# Cost after epoch 381: 0.000173
# Cost after epoch 382: 0.000173
# Cost after epoch 382: 0.000173
# Cost after epoch 382: 0.000173
# Cost after epoch 383: 0.000173
# Cost after epoch 383: 0.000173
# Cost after epoch 383: 0.000172
# Cost after epoch 384: 0.000172
# Cost after epoch 384: 0.000172
# Cost after epoch 384: 0.000172
# Cost after epoch 385: 0.000172
# Cost after epoch 385: 0.000172
# Cost after epoch 385: 0.000172
# Cost after epoch 386: 0.000172
# Cost after epoch 386: 0.000172
# Cost after epoch 386: 0.000172
# Cost after epoch 387: 0.000172
# Cost after epoch 387: 0.000172
# Cost after epoch 387: 0.000172
# Cost after epoch 388: 0.000172
# Cost after epoch 388: 0.000172
# Cost after epoch 388: 0.000172
# Cost after epoch 389: 0.000172
# Cost after epoch 389: 0.000172
# Cost after epoch 389: 0.000172
# Cost after epoch 390: 0.000172
# Cost after epoch 390: 0.000172
# Cost after epoch 390: 0.000172
# Cost after epoch 391: 0.000172
# Cost after epoch 391: 0.000172
# Cost after epoch 391: 0.000172
# Cost after epoch 392: 0.000172
# Cost after epoch 392: 0.000172
# Cost after epoch 392: 0.000172
# Cost after epoch 393: 0.000172
# Cost after epoch 393: 0.000172
# Cost after epoch 393: 0.000172
# Cost after epoch 394: 0.000172
# Cost after epoch 394: 0.000172
# Cost after epoch 394: 0.000172
# Cost after epoch 395: 0.000172
# Cost after epoch 395: 0.000172
# Cost after epoch 395: 0.000172
# Cost after epoch 396: 0.000172
# Cost after epoch 396: 0.000171
# Cost after epoch 396: 0.000171
# Cost after epoch 397: 0.000171
# Cost after epoch 397: 0.000171
# Cost after epoch 397: 0.000171
# Cost after epoch 398: 0.000171
# Cost after epoch 398: 0.000171
# Cost after epoch 398: 0.000171
# Cost after epoch 399: 0.000171
# Cost after epoch 399: 0.000171
# Cost after epoch 399: 0.000171
# Cost after epoch 400: 0.000171
# Cost after epoch 400: 0.000171
# Cost after epoch 400: 0.000171
# Cost after epoch 401: 0.000171
# Cost after epoch 401: 0.000171
# Cost after epoch 401: 0.000171
# Cost after epoch 402: 0.000171
# Cost after epoch 402: 0.000171
# Cost after epoch 402: 0.000171
# Cost after epoch 403: 0.000171
# Cost after epoch 403: 0.000171
# Cost after epoch 403: 0.000171
# Cost after epoch 404: 0.000171
# Cost after epoch 404: 0.000171
# Cost after epoch 404: 0.000171
# Cost after epoch 405: 0.000171
# Cost after epoch 405: 0.000171
# Cost after epoch 405: 0.000171
# Cost after epoch 406: 0.000171
# Cost after epoch 406: 0.000171
# Cost after epoch 406: 0.000171
# Cost after epoch 407: 0.000171
# Cost after epoch 407: 0.000171
# Cost after epoch 407: 0.000171
# Cost after epoch 408: 0.000171
# Cost after epoch 408: 0.000171
# Cost after epoch 408: 0.000171
# Cost after epoch 409: 0.000171
# Cost after epoch 409: 0.000170
# Cost after epoch 409: 0.000170
# Cost after epoch 410: 0.000170
# Cost after epoch 410: 0.000170
# Cost after epoch 410: 0.000170
# Cost after epoch 411: 0.000170
# Cost after epoch 411: 0.000170
# Cost after epoch 411: 0.000170
# Cost after epoch 412: 0.000170
# Cost after epoch 412: 0.000170
# Cost after epoch 412: 0.000170
# Cost after epoch 413: 0.000170
# Cost after epoch 413: 0.000170
# Cost after epoch 413: 0.000170
# Cost after epoch 414: 0.000170
# Cost after epoch 414: 0.000170
# Cost after epoch 414: 0.000170
# Cost after epoch 415: 0.000170
# Cost after epoch 415: 0.000170
# Cost after epoch 415: 0.000170
# Cost after epoch 416: 0.000170
# Cost after epoch 416: 0.000170
# Cost after epoch 416: 0.000170
# Cost after epoch 417: 0.000170
# Cost after epoch 417: 0.000170
# Cost after epoch 417: 0.000170
# Cost after epoch 418: 0.000170
# Cost after epoch 418: 0.000170
# Cost after epoch 418: 0.000170
# Cost after epoch 419: 0.000170
# Cost after epoch 419: 0.000170
# Cost after epoch 419: 0.000170
# Cost after epoch 420: 0.000170
# Cost after epoch 420: 0.000170
# Cost after epoch 420: 0.000170
# Cost after epoch 421: 0.000170
# Cost after epoch 421: 0.000170
# Cost after epoch 421: 0.000170
# Cost after epoch 422: 0.000170
# Cost after epoch 422: 0.000170
# Cost after epoch 422: 0.000169
# Cost after epoch 423: 0.000169
# Cost after epoch 423: 0.000169
# Cost after epoch 423: 0.000169
# Cost after epoch 424: 0.000169
# Cost after epoch 424: 0.000169
# Cost after epoch 424: 0.000169
# Cost after epoch 425: 0.000169
# Cost after epoch 425: 0.000169
# Cost after epoch 425: 0.000169
# Cost after epoch 426: 0.000169
# Cost after epoch 426: 0.000169
# Cost after epoch 426: 0.000169
# Cost after epoch 427: 0.000169
# Cost after epoch 427: 0.000169
# Cost after epoch 427: 0.000169
# Cost after epoch 428: 0.000169
# Cost after epoch 428: 0.000169
# Cost after epoch 428: 0.000169
# Cost after epoch 429: 0.000169
# Cost after epoch 429: 0.000169
# Cost after epoch 429: 0.000169
# Cost after epoch 430: 0.000169
# Cost after epoch 430: 0.000169
# Cost after epoch 430: 0.000169
# Cost after epoch 431: 0.000169
# Cost after epoch 431: 0.000169
# Cost after epoch 431: 0.000169
# Cost after epoch 432: 0.000169
# Cost after epoch 432: 0.000169
# Cost after epoch 432: 0.000169
# Cost after epoch 433: 0.000169
# Cost after epoch 433: 0.000169
# Cost after epoch 433: 0.000169
# Cost after epoch 434: 0.000169
# Cost after epoch 434: 0.000169
# Cost after epoch 434: 0.000169
# Cost after epoch 435: 0.000169
# Cost after epoch 435: 0.000169
# Cost after epoch 435: 0.000169
# Cost after epoch 436: 0.000168
# Cost after epoch 436: 0.000168
# Cost after epoch 436: 0.000168
# Cost after epoch 437: 0.000168
# Cost after epoch 437: 0.000168
# Cost after epoch 437: 0.000168
# Cost after epoch 438: 0.000168
# Cost after epoch 438: 0.000168
# Cost after epoch 438: 0.000168
# Cost after epoch 439: 0.000168
# Cost after epoch 439: 0.000168
# Cost after epoch 439: 0.000168
# Cost after epoch 440: 0.000168
# Cost after epoch 440: 0.000168
# Cost after epoch 440: 0.000168
# Cost after epoch 441: 0.000168
# Cost after epoch 441: 0.000168
# Cost after epoch 441: 0.000168
# Cost after epoch 442: 0.000168
# Cost after epoch 442: 0.000168
# Cost after epoch 442: 0.000168
# Cost after epoch 443: 0.000168
# Cost after epoch 443: 0.000168
# Cost after epoch 443: 0.000168
# Cost after epoch 444: 0.000168
# Cost after epoch 444: 0.000168
# Cost after epoch 444: 0.000168
# Cost after epoch 445: 0.000168
# Cost after epoch 445: 0.000168
# Cost after epoch 445: 0.000168
# Cost after epoch 446: 0.000168
# Cost after epoch 446: 0.000168
# Cost after epoch 446: 0.000168
# Cost after epoch 447: 0.000168
# Cost after epoch 447: 0.000168
# Cost after epoch 447: 0.000168
# Cost after epoch 448: 0.000168
# Cost after epoch 448: 0.000168
# Cost after epoch 448: 0.000168
# Cost after epoch 449: 0.000168
# Cost after epoch 449: 0.000167
# Cost after epoch 449: 0.000167
# Cost after epoch 450: 0.000167
# Cost after epoch 450: 0.000167
# Cost after epoch 450: 0.000167
# Cost after epoch 451: 0.000167
# Cost after epoch 451: 0.000167
# Cost after epoch 451: 0.000167
# Cost after epoch 452: 0.000167
# Cost after epoch 452: 0.000167
# Cost after epoch 452: 0.000167
# Cost after epoch 453: 0.000167
# Cost after epoch 453: 0.000167
# Cost after epoch 453: 0.000167
# Cost after epoch 454: 0.000167
# Cost after epoch 454: 0.000167
# Cost after epoch 454: 0.000167
# Cost after epoch 455: 0.000167
# Cost after epoch 455: 0.000167
# Cost after epoch 455: 0.000167
# Cost after epoch 456: 0.000167
# Cost after epoch 456: 0.000167
# Cost after epoch 456: 0.000167
# Cost after epoch 457: 0.000167
# Cost after epoch 457: 0.000167
# Cost after epoch 457: 0.000167
# Cost after epoch 458: 0.000167
# Cost after epoch 458: 0.000167
# Cost after epoch 458: 0.000167
# Cost after epoch 459: 0.000167
# Cost after epoch 459: 0.000167
# Cost after epoch 459: 0.000167
# Cost after epoch 460: 0.000167
# Cost after epoch 460: 0.000167
# Cost after epoch 460: 0.000167
# Cost after epoch 461: 0.000167
# Cost after epoch 461: 0.000167
# Cost after epoch 461: 0.000167
# Cost after epoch 462: 0.000167
# Cost after epoch 462: 0.000167
# Cost after epoch 462: 0.000167
# Cost after epoch 463: 0.000166
# Cost after epoch 463: 0.000166
# Cost after epoch 463: 0.000166
# Cost after epoch 464: 0.000166
# Cost after epoch 464: 0.000166
# Cost after epoch 464: 0.000166
# Cost after epoch 465: 0.000166
# Cost after epoch 465: 0.000166
# Cost after epoch 465: 0.000166
# Cost after epoch 466: 0.000166
# Cost after epoch 466: 0.000166
# Cost after epoch 466: 0.000166
# Cost after epoch 467: 0.000166
# Cost after epoch 467: 0.000166
# Cost after epoch 467: 0.000166
# Cost after epoch 468: 0.000166
# Cost after epoch 468: 0.000166
# Cost after epoch 468: 0.000166
# Cost after epoch 469: 0.000166
# Cost after epoch 469: 0.000166
# Cost after epoch 469: 0.000166
# Cost after epoch 470: 0.000166
# Cost after epoch 470: 0.000166
# Cost after epoch 470: 0.000166
# Cost after epoch 471: 0.000166
# Cost after epoch 471: 0.000166
# Cost after epoch 471: 0.000166
# Cost after epoch 472: 0.000166
# Cost after epoch 472: 0.000166
# Cost after epoch 472: 0.000166
# Cost after epoch 473: 0.000166
# Cost after epoch 473: 0.000166
# Cost after epoch 473: 0.000166
# Cost after epoch 474: 0.000166
# Cost after epoch 474: 0.000166
# Cost after epoch 474: 0.000166
# Cost after epoch 475: 0.000166
# Cost after epoch 475: 0.000166
# Cost after epoch 475: 0.000166
# Cost after epoch 476: 0.000166
# Cost after epoch 476: 0.000166
# Cost after epoch 476: 0.000166
# Cost after epoch 477: 0.000165
# Cost after epoch 477: 0.000165
# Cost after epoch 477: 0.000165
# Cost after epoch 478: 0.000165
# Cost after epoch 478: 0.000165
# Cost after epoch 478: 0.000165
# Cost after epoch 479: 0.000165
# Cost after epoch 479: 0.000165
# Cost after epoch 479: 0.000165
# Cost after epoch 480: 0.000165
# Cost after epoch 480: 0.000165
# Cost after epoch 480: 0.000165
# Cost after epoch 481: 0.000165
# Cost after epoch 481: 0.000165
# Cost after epoch 481: 0.000165
# Cost after epoch 482: 0.000165
# Cost after epoch 482: 0.000165
# Cost after epoch 482: 0.000165
# Cost after epoch 483: 0.000165
# Cost after epoch 483: 0.000165
# Cost after epoch 483: 0.000165
# Cost after epoch 484: 0.000165
# Cost after epoch 484: 0.000165
# Cost after epoch 484: 0.000165
# Cost after epoch 485: 0.000165
# Cost after epoch 485: 0.000165
# Cost after epoch 485: 0.000165
# Cost after epoch 486: 0.000165
# Cost after epoch 486: 0.000165
# Cost after epoch 486: 0.000165
# Cost after epoch 487: 0.000165
# Cost after epoch 487: 0.000165
# Cost after epoch 487: 0.000165
# Cost after epoch 488: 0.000165
# Cost after epoch 488: 0.000165
# Cost after epoch 488: 0.000165
# Cost after epoch 489: 0.000165
# Cost after epoch 489: 0.000165
# Cost after epoch 489: 0.000165
# Cost after epoch 490: 0.000165
# Cost after epoch 490: 0.000165
# Cost after epoch 490: 0.000165
# Cost after epoch 491: 0.000165
# Cost after epoch 491: 0.000164
# Cost after epoch 491: 0.000164
# Cost after epoch 492: 0.000164
# Cost after epoch 492: 0.000164
# Cost after epoch 492: 0.000164
# Cost after epoch 493: 0.000164
# Cost after epoch 493: 0.000164
# Cost after epoch 493: 0.000164
# Cost after epoch 494: 0.000164
# Cost after epoch 494: 0.000164
# Cost after epoch 494: 0.000164
# Cost after epoch 495: 0.000164
# Cost after epoch 495: 0.000164
# Cost after epoch 495: 0.000164
# Cost after epoch 496: 0.000164
# Cost after epoch 496: 0.000164
# Cost after epoch 496: 0.000164
# Cost after epoch 497: 0.000164
# Cost after epoch 497: 0.000164
# Cost after epoch 497: 0.000164
# Cost after epoch 498: 0.000164
# Cost after epoch 498: 0.000164
# Cost after epoch 498: 0.000164
# Cost after epoch 499: 0.000164
# Cost after epoch 499: 0.000164
# Cost after epoch 499: 0.000164
# Cost after epoch 500: 0.000164
# Cost after epoch 500: 0.000164
# Cost after epoch 500: 0.000164
# Cost after epoch 501: 0.000164
# Cost after epoch 501: 0.000164
# Cost after epoch 501: 0.000164
# Cost after epoch 502: 0.000164
# Cost after epoch 502: 0.000164
# Cost after epoch 502: 0.000164
# Cost after epoch 503: 0.000164
# Cost after epoch 503: 0.000164
# Cost after epoch 503: 0.000164
# Cost after epoch 504: 0.000164
# Cost after epoch 504: 0.000164
# Cost after epoch 504: 0.000164
# Cost after epoch 505: 0.000164
# Cost after epoch 505: 0.000164
# Cost after epoch 505: 0.000163
# Cost after epoch 506: 0.000163
# Cost after epoch 506: 0.000163
# Cost after epoch 506: 0.000163
# Cost after epoch 507: 0.000163
# Cost after epoch 507: 0.000163
# Cost after epoch 507: 0.000163
# Cost after epoch 508: 0.000163
# Cost after epoch 508: 0.000163
# Cost after epoch 508: 0.000163
# Cost after epoch 509: 0.000163
# Cost after epoch 509: 0.000163
# Cost after epoch 509: 0.000163
# Cost after epoch 510: 0.000163
# Cost after epoch 510: 0.000163
# Cost after epoch 510: 0.000163
# Cost after epoch 511: 0.000163
# Cost after epoch 511: 0.000163
# Cost after epoch 511: 0.000163
# Cost after epoch 512: 0.000163
# Cost after epoch 512: 0.000163
# Cost after epoch 512: 0.000163
# Cost after epoch 513: 0.000163
# Cost after epoch 513: 0.000163
# Cost after epoch 513: 0.000163
# Cost after epoch 514: 0.000163
# Cost after epoch 514: 0.000163
# Cost after epoch 514: 0.000163
# Cost after epoch 515: 0.000163
# Cost after epoch 515: 0.000163
# Cost after epoch 515: 0.000163
# Cost after epoch 516: 0.000163
# Cost after epoch 516: 0.000163
# Cost after epoch 516: 0.000163
# Cost after epoch 517: 0.000163
# Cost after epoch 517: 0.000163
# Cost after epoch 517: 0.000163
# Cost after epoch 518: 0.000163
# Cost after epoch 518: 0.000163
# Cost after epoch 518: 0.000163
# Cost after epoch 519: 0.000163
# Cost after epoch 519: 0.000163
# ...
# Cost after epoch 4834: 0.000065
# Cost after epoch 4835: 0.000065
# Cost after epoch 4835: 0.000065
# Cost after epoch 4835: 0.000065
# Cost after epoch 4836: 0.000065
# Cost after epoch 4836: 0.000065
# Cost after epoch 4836: 0.000065
# Cost after epoch 4837: 0.000065
# Cost after epoch 4837: 0.000065
# Cost after epoch 4837: 0.000065
# Cost after epoch 4838: 0.000065
# Cost after epoch 4838: 0.000065
# Cost after epoch 4838: 0.000065
# Cost after epoch 4839: 0.000065
# Cost after epoch 4839: 0.000065
# Cost after epoch 4839: 0.000065
# Cost after epoch 4840: 0.000065
# Cost after epoch 4840: 0.000065
# Cost after epoch 4840: 0.000065
# Cost after epoch 4841: 0.000065
# Cost after epoch 4841: 0.000065
# Cost after epoch 4841: 0.000065
# Cost after epoch 4842: 0.000065
# Cost after epoch 4842: 0.000065
# Cost after epoch 4842: 0.000065
# Cost after epoch 4843: 0.000065
# Cost after epoch 4843: 0.000065
# Cost after epoch 4843: 0.000065
# Cost after epoch 4844: 0.000065
# Cost after epoch 4844: 0.000065
# Cost after epoch 4844: 0.000065
# Cost after epoch 4845: 0.000065
# Cost after epoch 4845: 0.000065
# Cost after epoch 4845: 0.000065
# Cost after epoch 4846: 0.000065
# Cost after epoch 4846: 0.000065
# Cost after epoch 4846: 0.000065
# Cost after epoch 4847: 0.000065
# Cost after epoch 4847: 0.000065
# Cost after epoch 4847: 0.000065
# Cost after epoch 4848: 0.000065
# Cost after epoch 4848: 0.000065
# Cost after epoch 4848: 0.000065
# Cost after epoch 4849: 0.000065
# Cost after epoch 4849: 0.000065
# Cost after epoch 4849: 0.000065
# Cost after epoch 4850: 0.000065
# Cost after epoch 4850: 0.000065
# Cost after epoch 4850: 0.000065
# Cost after epoch 4851: 0.000065
# Cost after epoch 4851: 0.000065
# Cost after epoch 4851: 0.000065
# Cost after epoch 4852: 0.000065
# Cost after epoch 4852: 0.000065
# Cost after epoch 4852: 0.000065
# Cost after epoch 4853: 0.000065
# Cost after epoch 4853: 0.000065
# Cost after epoch 4853: 0.000065
# Cost after epoch 4854: 0.000065
# Cost after epoch 4854: 0.000065
# Cost after epoch 4854: 0.000065
# Cost after epoch 4855: 0.000065
# Cost after epoch 4855: 0.000065
# Cost after epoch 4855: 0.000065
# Cost after epoch 4856: 0.000065
# Cost after epoch 4856: 0.000065
# Cost after epoch 4856: 0.000065
# Cost after epoch 4857: 0.000065
# Cost after epoch 4857: 0.000065
# Cost after epoch 4857: 0.000065
# Cost after epoch 4858: 0.000065
# Cost after epoch 4858: 0.000065
# Cost after epoch 4858: 0.000065
# Cost after epoch 4859: 0.000065
# Cost after epoch 4859: 0.000065
# Cost after epoch 4859: 0.000065
# Cost after epoch 4860: 0.000065
# Cost after epoch 4860: 0.000065
# Cost after epoch 4860: 0.000065
# Cost after epoch 4861: 0.000065
# Cost after epoch 4861: 0.000065
# Cost after epoch 4861: 0.000065
# Cost after epoch 4862: 0.000065
# Cost after epoch 4862: 0.000065
# Cost after epoch 4862: 0.000065
# Cost after epoch 4863: 0.000064
# Cost after epoch 4863: 0.000064
# Cost after epoch 4863: 0.000064
# Cost after epoch 4864: 0.000064
# Cost after epoch 4864: 0.000064
# Cost after epoch 4864: 0.000064
# Cost after epoch 4865: 0.000064
# Cost after epoch 4865: 0.000064
# Cost after epoch 4865: 0.000064
# Cost after epoch 4866: 0.000064
# Cost after epoch 4866: 0.000064
# Cost after epoch 4866: 0.000064
# Cost after epoch 4867: 0.000064
# Cost after epoch 4867: 0.000064
# Cost after epoch 4867: 0.000064
# Cost after epoch 4868: 0.000064
# Cost after epoch 4868: 0.000064
# Cost after epoch 4868: 0.000064
# Cost after epoch 4869: 0.000064
# Cost after epoch 4869: 0.000064
# Cost after epoch 4869: 0.000064
# Cost after epoch 4870: 0.000064
# Cost after epoch 4870: 0.000064
# Cost after epoch 4870: 0.000064
# Cost after epoch 4871: 0.000064
# Cost after epoch 4871: 0.000064
# Cost after epoch 4871: 0.000064
# Cost after epoch 4872: 0.000064
# Cost after epoch 4872: 0.000064
# Cost after epoch 4872: 0.000064
# Cost after epoch 4873: 0.000064
# Cost after epoch 4873: 0.000064
# Cost after epoch 4873: 0.000064
# Cost after epoch 4874: 0.000064
# Cost after epoch 4874: 0.000064
# Cost after epoch 4874: 0.000064
# Cost after epoch 4875: 0.000064
# Cost after epoch 4875: 0.000064
# Cost after epoch 4875: 0.000064
# Cost after epoch 4876: 0.000064
# Cost after epoch 4876: 0.000064
# Cost after epoch 4876: 0.000064
# Cost after epoch 4877: 0.000064
# Cost after epoch 4877: 0.000064
# Cost after epoch 4877: 0.000064
# Cost after epoch 4878: 0.000064
# Cost after epoch 4878: 0.000064
# Cost after epoch 4878: 0.000064
# Cost after epoch 4879: 0.000064
# Cost after epoch 4879: 0.000064
# Cost after epoch 4879: 0.000064
# Cost after epoch 4880: 0.000064
# Cost after epoch 4880: 0.000064
# Cost after epoch 4880: 0.000064
# Cost after epoch 4881: 0.000064
# Cost after epoch 4881: 0.000064
# Cost after epoch 4881: 0.000064
# Cost after epoch 4882: 0.000064
# Cost after epoch 4882: 0.000064
# Cost after epoch 4882: 0.000064
# Cost after epoch 4883: 0.000064
# Cost after epoch 4883: 0.000064
# Cost after epoch 4883: 0.000064
# Cost after epoch 4884: 0.000064
# Cost after epoch 4884: 0.000064
# Cost after epoch 4884: 0.000064
# Cost after epoch 4885: 0.000064
# Cost after epoch 4885: 0.000064
# Cost after epoch 4885: 0.000064
# Cost after epoch 4886: 0.000064
# Cost after epoch 4886: 0.000064
# Cost after epoch 4886: 0.000064
# Cost after epoch 4887: 0.000064
# Cost after epoch 4887: 0.000064
# Cost after epoch 4887: 0.000064
# Cost after epoch 4888: 0.000064
# Cost after epoch 4888: 0.000064
# Cost after epoch 4888: 0.000064
# Cost after epoch 4889: 0.000064
# Cost after epoch 4889: 0.000064
# Cost after epoch 4889: 0.000064
# Cost after epoch 4890: 0.000064
# Cost after epoch 4890: 0.000064
# Cost after epoch 4890: 0.000064
# Cost after epoch 4891: 0.000064
# Cost after epoch 4891: 0.000064
# Cost after epoch 4891: 0.000064
# Cost after epoch 4892: 0.000064
# Cost after epoch 4892: 0.000064
# Cost after epoch 4892: 0.000064
# Cost after epoch 4893: 0.000064
# Cost after epoch 4893: 0.000064
# Cost after epoch 4893: 0.000064
# Cost after epoch 4894: 0.000064
# Cost after epoch 4894: 0.000064
# Cost after epoch 4894: 0.000064
# Cost after epoch 4895: 0.000064
# Cost after epoch 4895: 0.000064
# Cost after epoch 4895: 0.000064
# Cost after epoch 4896: 0.000064
# Cost after epoch 4896: 0.000064
# Cost after epoch 4896: 0.000064
# Cost after epoch 4897: 0.000064
# Cost after epoch 4897: 0.000064
# Cost after epoch 4897: 0.000064
# Cost after epoch 4898: 0.000064
# Cost after epoch 4898: 0.000064
# Cost after epoch 4898: 0.000064
# Cost after epoch 4899: 0.000064
# Cost after epoch 4899: 0.000064
# Cost after epoch 4899: 0.000064
# Cost after epoch 4900: 0.000064
# Cost after epoch 4900: 0.000064
# Cost after epoch 4900: 0.000064
# Cost after epoch 4901: 0.000064
# Cost after epoch 4901: 0.000064
# Cost after epoch 4901: 0.000064
# Cost after epoch 4902: 0.000064
# Cost after epoch 4902: 0.000064
# Cost after epoch 4902: 0.000064
# Cost after epoch 4903: 0.000064
# Cost after epoch 4903: 0.000064
# Cost after epoch 4903: 0.000064
# Cost after epoch 4904: 0.000064
# Cost after epoch 4904: 0.000064
# Cost after epoch 4904: 0.000064
# Cost after epoch 4905: 0.000064
# Cost after epoch 4905: 0.000064
# Cost after epoch 4905: 0.000064
# Cost after epoch 4906: 0.000064
# Cost after epoch 4906: 0.000064
# Cost after epoch 4906: 0.000064
# Cost after epoch 4907: 0.000064
# Cost after epoch 4907: 0.000064
# Cost after epoch 4907: 0.000064
# Cost after epoch 4908: 0.000064
# Cost after epoch 4908: 0.000064
# Cost after epoch 4908: 0.000064
# Cost after epoch 4909: 0.000064
# Cost after epoch 4909: 0.000064
# Cost after epoch 4909: 0.000064
# Cost after epoch 4910: 0.000064
# Cost after epoch 4910: 0.000064
# Cost after epoch 4910: 0.000064
# Cost after epoch 4911: 0.000064
# Cost after epoch 4911: 0.000064
# Cost after epoch 4911: 0.000064
# Cost after epoch 4912: 0.000064
# Cost after epoch 4912: 0.000064
# Cost after epoch 4912: 0.000064
# Cost after epoch 4913: 0.000064
# Cost after epoch 4913: 0.000064
# Cost after epoch 4913: 0.000064
# Cost after epoch 4914: 0.000064
# Cost after epoch 4914: 0.000064
# Cost after epoch 4914: 0.000064
# Cost after epoch 4915: 0.000064
# Cost after epoch 4915: 0.000064
# Cost after epoch 4915: 0.000064
# Cost after epoch 4916: 0.000064
# Cost after epoch 4916: 0.000064
# Cost after epoch 4916: 0.000064
# Cost after epoch 4917: 0.000064
# Cost after epoch 4917: 0.000064
# Cost after epoch 4917: 0.000064
# Cost after epoch 4918: 0.000064
# Cost after epoch 4918: 0.000064
# Cost after epoch 4918: 0.000064
# Cost after epoch 4919: 0.000064
# Cost after epoch 4919: 0.000064
# Cost after epoch 4919: 0.000064
# Cost after epoch 4920: 0.000064
# Cost after epoch 4920: 0.000064
# Cost after epoch 4920: 0.000064
# Cost after epoch 4921: 0.000064
# Cost after epoch 4921: 0.000064
# Cost after epoch 4921: 0.000064
# Cost after epoch 4922: 0.000064
# Cost after epoch 4922: 0.000064
# Cost after epoch 4922: 0.000064
# Cost after epoch 4923: 0.000064
# Cost after epoch 4923: 0.000064
# Cost after epoch 4923: 0.000064
# Cost after epoch 4924: 0.000064
# Cost after epoch 4924: 0.000064
# Cost after epoch 4924: 0.000064
# Cost after epoch 4925: 0.000064
# Cost after epoch 4925: 0.000064
# Cost after epoch 4925: 0.000064
# Cost after epoch 4926: 0.000064
# Cost after epoch 4926: 0.000064
# Cost after epoch 4926: 0.000064
# Cost after epoch 4927: 0.000064
# Cost after epoch 4927: 0.000064
# Cost after epoch 4927: 0.000064
# Cost after epoch 4928: 0.000064
# Cost after epoch 4928: 0.000064
# Cost after epoch 4928: 0.000064
# Cost after epoch 4929: 0.000064
# Cost after epoch 4929: 0.000064
# Cost after epoch 4929: 0.000064
# Cost after epoch 4930: 0.000064
# Cost after epoch 4930: 0.000064
# Cost after epoch 4930: 0.000064
# Cost after epoch 4931: 0.000064
# Cost after epoch 4931: 0.000064
# Cost after epoch 4931: 0.000064
# Cost after epoch 4932: 0.000064
# Cost after epoch 4932: 0.000064
# Cost after epoch 4932: 0.000064
# Cost after epoch 4933: 0.000064
# Cost after epoch 4933: 0.000064
# Cost after epoch 4933: 0.000064
# Cost after epoch 4934: 0.000064
# Cost after epoch 4934: 0.000064
# Cost after epoch 4934: 0.000064
# Cost after epoch 4935: 0.000064
# Cost after epoch 4935: 0.000064
# Cost after epoch 4935: 0.000064
# Cost after epoch 4936: 0.000064
# Cost after epoch 4936: 0.000064
# Cost after epoch 4936: 0.000064
# Cost after epoch 4937: 0.000064
# Cost after epoch 4937: 0.000064
# Cost after epoch 4937: 0.000064
# Cost after epoch 4938: 0.000064
# Cost after epoch 4938: 0.000064
# Cost after epoch 4938: 0.000064
# Cost after epoch 4939: 0.000064
# Cost after epoch 4939: 0.000064
# Cost after epoch 4939: 0.000064
# Cost after epoch 4940: 0.000064
# Cost after epoch 4940: 0.000064
# Cost after epoch 4940: 0.000064
# Cost after epoch 4941: 0.000064
# Cost after epoch 4941: 0.000064
# Cost after epoch 4941: 0.000064
# Cost after epoch 4942: 0.000064
# Cost after epoch 4942: 0.000064
# Cost after epoch 4942: 0.000064
# Cost after epoch 4943: 0.000064
# Cost after epoch 4943: 0.000064
# Cost after epoch 4943: 0.000064
# Cost after epoch 4944: 0.000064
# Cost after epoch 4944: 0.000064
# Cost after epoch 4944: 0.000064
# Cost after epoch 4945: 0.000064
# Cost after epoch 4945: 0.000064
# Cost after epoch 4945: 0.000064
# Cost after epoch 4946: 0.000064
# Cost after epoch 4946: 0.000064
# Cost after epoch 4946: 0.000064
# Cost after epoch 4947: 0.000064
# Cost after epoch 4947: 0.000064
# Cost after epoch 4947: 0.000064
# Cost after epoch 4948: 0.000064
# Cost after epoch 4948: 0.000064
# Cost after epoch 4948: 0.000064
# Cost after epoch 4949: 0.000064
# Cost after epoch 4949: 0.000064
# Cost after epoch 4949: 0.000064
# Cost after epoch 4950: 0.000064
# Cost after epoch 4950: 0.000064
# Cost after epoch 4950: 0.000064
# Cost after epoch 4951: 0.000064
# Cost after epoch 4951: 0.000064
# Cost after epoch 4951: 0.000064
# Cost after epoch 4952: 0.000064
# Cost after epoch 4952: 0.000064
# Cost after epoch 4952: 0.000064
# Cost after epoch 4953: 0.000064
# Cost after epoch 4953: 0.000064
# Cost after epoch 4953: 0.000064
# Cost after epoch 4954: 0.000064
# Cost after epoch 4954: 0.000064
# Cost after epoch 4954: 0.000064
# Cost after epoch 4955: 0.000064
# Cost after epoch 4955: 0.000064
# Cost after epoch 4955: 0.000064
# Cost after epoch 4956: 0.000064
# Cost after epoch 4956: 0.000064
# Cost after epoch 4956: 0.000064
# Cost after epoch 4957: 0.000064
# Cost after epoch 4957: 0.000064
# Cost after epoch 4957: 0.000064
# Cost after epoch 4958: 0.000064
# Cost after epoch 4958: 0.000064
# Cost after epoch 4958: 0.000064
# Cost after epoch 4959: 0.000064
# Cost after epoch 4959: 0.000064
# Cost after epoch 4959: 0.000064
# Cost after epoch 4960: 0.000064
# Cost after epoch 4960: 0.000064
# Cost after epoch 4960: 0.000064
# Cost after epoch 4961: 0.000064
# Cost after epoch 4961: 0.000064
# Cost after epoch 4961: 0.000064
# Cost after epoch 4962: 0.000064
# Cost after epoch 4962: 0.000064
# Cost after epoch 4962: 0.000064
# Cost after epoch 4963: 0.000064
# Cost after epoch 4963: 0.000064
# Cost after epoch 4963: 0.000064
# Cost after epoch 4964: 0.000064
# Cost after epoch 4964: 0.000064
# Cost after epoch 4964: 0.000064
# Cost after epoch 4965: 0.000064
# Cost after epoch 4965: 0.000064
# Cost after epoch 4965: 0.000064
# Cost after epoch 4966: 0.000064
# Cost after epoch 4966: 0.000064
# Cost after epoch 4966: 0.000064
# Cost after epoch 4967: 0.000064
# Cost after epoch 4967: 0.000064
# Cost after epoch 4967: 0.000064
# Cost after epoch 4968: 0.000064
# Cost after epoch 4968: 0.000064
# Cost after epoch 4968: 0.000064
# Cost after epoch 4969: 0.000064
# Cost after epoch 4969: 0.000064
# Cost after epoch 4969: 0.000064
# Cost after epoch 4970: 0.000064
# Cost after epoch 4970: 0.000064
# Cost after epoch 4970: 0.000064
# Cost after epoch 4971: 0.000064
# Cost after epoch 4971: 0.000064
# Cost after epoch 4971: 0.000064
# Cost after epoch 4972: 0.000064
# Cost after epoch 4972: 0.000064
# Cost after epoch 4972: 0.000064
# Cost after epoch 4973: 0.000064
# Cost after epoch 4973: 0.000064
# Cost after epoch 4973: 0.000064
# Cost after epoch 4974: 0.000064
# Cost after epoch 4974: 0.000064
# Cost after epoch 4974: 0.000064
# Cost after epoch 4975: 0.000064
# Cost after epoch 4975: 0.000064
# Cost after epoch 4975: 0.000064
# Cost after epoch 4976: 0.000064
# Cost after epoch 4976: 0.000064
# Cost after epoch 4976: 0.000064
# Cost after epoch 4977: 0.000064
# Cost after epoch 4977: 0.000064
# Cost after epoch 4977: 0.000064
# Cost after epoch 4978: 0.000064
# Cost after epoch 4978: 0.000064
# Cost after epoch 4978: 0.000064
# Cost after epoch 4979: 0.000064
# Cost after epoch 4979: 0.000064
# Cost after epoch 4979: 0.000064
# Cost after epoch 4980: 0.000064
# Cost after epoch 4980: 0.000064
# Cost after epoch 4980: 0.000064
# Cost after epoch 4981: 0.000064
# Cost after epoch 4981: 0.000064
# Cost after epoch 4981: 0.000064
# Cost after epoch 4982: 0.000064
# Cost after epoch 4982: 0.000064
# Cost after epoch 4982: 0.000064
# Cost after epoch 4983: 0.000064
# Cost after epoch 4983: 0.000064
# Cost after epoch 4983: 0.000063
# Cost after epoch 4984: 0.000063
# Cost after epoch 4984: 0.000063
# Cost after epoch 4984: 0.000063
# Cost after epoch 4985: 0.000063
# Cost after epoch 4985: 0.000063
# Cost after epoch 4985: 0.000063
# Cost after epoch 4986: 0.000063
# Cost after epoch 4986: 0.000063
# Cost after epoch 4986: 0.000063
# Cost after epoch 4987: 0.000063
# Cost after epoch 4987: 0.000063
# Cost after epoch 4987: 0.000063
# Cost after epoch 4988: 0.000063
# Cost after epoch 4988: 0.000063
# Cost after epoch 4988: 0.000063
# Cost after epoch 4989: 0.000063
# Cost after epoch 4989: 0.000063
# Cost after epoch 4989: 0.000063
# Cost after epoch 4990: 0.000063
# Cost after epoch 4990: 0.000063
# Cost after epoch 4990: 0.000063
# Cost after epoch 4991: 0.000063
# Cost after epoch 4991: 0.000063
# Cost after epoch 4991: 0.000063
# Cost after epoch 4992: 0.000063
# Cost after epoch 4992: 0.000063
# Cost after epoch 4992: 0.000063
# Cost after epoch 4993: 0.000063
# Cost after epoch 4993: 0.000063
# Cost after epoch 4993: 0.000063
# Cost after epoch 4994: 0.000063
# Cost after epoch 4994: 0.000063
# Cost after epoch 4994: 0.000063
# Cost after epoch 4995: 0.000063
# Cost after epoch 4995: 0.000063
# Cost after epoch 4995: 0.000063
# Cost after epoch 4996: 0.000063
# Cost after epoch 4996: 0.000063
# Cost after epoch 4996: 0.000063
# Cost after epoch 4997: 0.000063
# Cost after epoch 4997: 0.000063
# Cost after epoch 4997: 0.000063
# Cost after epoch 4998: 0.000063
# Cost after epoch 4998: 0.000063
# Cost after epoch 4998: 0.000063
# Cost after epoch 4999: 0.000063
# Cost after epoch 4999: 0.000063
# Cost after epoch 4999: 0.000063
# w = [[ 1.09953111]
#  [-1.85892645]]
# b = [4.14791583]
# dw = [[-6.60554364e-05]
#  [ 1.37382432e-04]]
# db = [-6.22935637e-05]

# %% [markdown]
# ### Adam
# Adam (Adaptive momentum algorithm) combines momentum and RMSprop approaches:
# - computes adaptive learning rates;
# - storing an exponentially moving average of past squared gradients
# - and uses scaling of the gradients:
# $V^{corr}_t = \dfrac{V_t}{1 − β^t}$
#
# Parameters:
# - $η$ - learning rate
# - β_1 = 0.9
# - β_2 = 0.999
# - ϵ = 10−8
#
# The moving averages of past and past squared gradients $V_t$ and $S_t$ respectively are computed as follows:
#
# $V_t = β_1 V_{t − 1} + ( 1 − β_1 ) g_t \\ S_t = β_2 S_{t − 1} + ( 1 − β_2 ) g^2_t$
#
# Adam update rule for the model weights:
#
# $θ_t + 1 = θ_t − \dfrac{η}{\sqrt{S^{corr}_t}+ ϵ}  V_t$
#
# > Ref: [Адам - ​​последние тенденции в глубокой оптимизации обучения.
# ](https://machinelearningmastery.ru/adam-latest-trends-in-deep-learning-optimization-6be9a291375c/)
# >
# > $m_t = β_1 m_{t − 1} + (1 − β_1) g_t \\ v_t = β_2 v_{t − 1} + ( 1 − β_2 ) g^2_t$
# > The shift corrected the estimates for the first and second moments.
# >
# > $\hat{V_t}=\dfrac{V_t}{1-β_1^t} \\ \hat{S_t}=\dfrac{S_t}{1-β_2^t}$

# %%
def ADAM(w, b, X, Y, epochs, learning_rate=1e-1, print_cost=False, ksi=1e-8, beta_1=0.9, beta_2=0.999):
    # print(f"ADAM curr LR", learning_rate)
    costs = []
    V_dw, V_db, S_dw, S_db = 0, 0, 0, 0
    # Avoiding division by zero
    for epoch in range(1, epochs + 1):
        # Cost and gradient calculation 
        grads, cost = propagate(w, b, X, Y)
        
        # Retrieve derivatives from grads
        dw = grads["dw"]
        db = grads["db"]
        
        # V_dw, V_db, S_dw, S_db = 0, 0, 0, 0
        
        # Formula from the 5 Lecture
        V_dw = beta_1 * V_dw + (1 - beta_1) * dw 
        V_db = beta_1 * V_db + (1 - beta_1) * db 
        
        S_dw = beta_2 * S_dw + (1 - beta_2) * np.power(dw, 2)
        S_db = beta_2 * S_db + (1 - beta_2) * np.power(db, 2)
        # + ksi also 4 Avoiding division by zero
        V_dw_hat = V_dw / (1 - (beta_1 ** epoch))
        V_db_hat = V_db / (1 - (beta_1 ** epoch))
        S_dw_hat = S_dw / (1 - (beta_2 ** epoch))
        S_db_hat = S_db / (1 - (beta_2 ** epoch))

        # Update rule from Lecture and MachineLearningMastery
        w -= learning_rate * (V_dw_hat / (np.sqrt(S_dw_hat) + ksi))
        b -= learning_rate * (V_db_hat / (np.sqrt(S_db_hat) + ksi))
 
        # Record the costs
        if epoch % 100 == 0:
            costs.append(cost)
        
        # Print the cost every 100 training iterations
        if print_cost and epoch % 100 == 0:
            print ("Cost after iteration %i: %f" %(epoch, cost))
    
    params = {
        "w": w,
        "b": b,
    }
    
    grads = {
        "dw": dw,
        "db": db,
    }
    
    return params, grads, costs

# %%
params, grads, costs = ADAM(w, b, X, Y,
    epochs=5000,
)

print("w = " + str(params["w"]))
print("b = " + str(params["b"]))
print("dw = " + str(grads["dw"]))
print("db = " + str(grads["db"]))
# Out:
# Cost after iteration 100: 1.027078
# Cost after iteration 200: 1.025659
# Cost after iteration 300: 1.025285
# Cost after iteration 400: 1.025122
# Cost after iteration 500: 1.025033
# Cost after iteration 600: 1.024979
# Cost after iteration 700: 1.024944
# Cost after iteration 800: 1.024918
# Cost after iteration 900: 1.024900
# Cost after iteration 1000: 1.024886
# Cost after iteration 1100: 1.024876
# Cost after iteration 1200: 1.024868
# Cost after iteration 1300: 1.024861
# Cost after iteration 1400: 1.024856
# Cost after iteration 1500: 1.024851
# Cost after iteration 1600: 1.024848
# Cost after iteration 1700: 1.024845
# Cost after iteration 1800: 1.024842
# Cost after iteration 1900: 1.024840
# Cost after iteration 2000: 1.024838
# Cost after iteration 2100: 1.024837
# Cost after iteration 2200: 1.024836
# Cost after iteration 2300: 1.024834
# Cost after iteration 2400: 1.024833
# Cost after iteration 2500: 1.024833
# Cost after iteration 2600: 1.024832
# Cost after iteration 2700: 1.024831
# Cost after iteration 2800: 1.024831
# Cost after iteration 2900: 1.024830
# Cost after iteration 3000: 1.024830
# Cost after iteration 3100: 1.024830
# Cost after iteration 3200: 1.024829
# Cost after iteration 3300: 1.024829
# Cost after iteration 3400: 1.024829
# Cost after iteration 3500: 1.024829
# Cost after iteration 3600: 1.024828
# Cost after iteration 3700: 1.024828
# Cost after iteration 3800: 1.024828
# Cost after iteration 3900: 1.024828
# Cost after iteration 4000: 1.024828
# Cost after iteration 4100: 1.024828
# Cost after iteration 4200: 1.024828
# Cost after iteration 4300: 1.024828
# Cost after iteration 4400: 1.024828
# Cost after iteration 4500: 1.024828
# Cost after iteration 4600: 1.024828
# Cost after iteration 4700: 1.024827
# Cost after iteration 4800: 1.024827
# Cost after iteration 4900: 1.024827
# Cost after iteration 5000: 1.024827
# w = [[-0.10000003]
#  [ 0.10000005]]
# b = [-0.10000018]
# dw = [[-0.65299434]
#  [ 2.91786112]]
# db = [-0.17833539]

# %% [markdown]
# ### 3.	For three modifications of gradient descent (GD, SGD and Adam) plot the learning curves (dependence of the value of the loss function on the iteration number), apply models with different values of the learning rate (at least 5 different learning rates). How does it affect the accuracy of the model?

# %%
learning_rates = [0.001, 0.005, 0.01, 0.05, 0.1]

# %%
GD_trained = []

for currLR in learning_rates:
    print(f"Current learning rate {currLR}")
    gd_with_LR = model(
        X_train, 
        y_train, 
        X_test, 
        y_test, 
        optimization_algorithm=optimize, 
        learning_rate=currLR, 
        print_cost=False,
    )
    GD_trained.append(gd_with_LR)
# Out:
# Current learning rate 0.001
# train accuracy: 72.52044081052257 %
# test accuracy: 72.70788912579957 %
# Current learning rate 0.005
# train accuracy: 77.10629221471739 %
# test accuracy: 74.73347547974413 %
# Current learning rate 0.01
# train accuracy: 78.35051546391753 %
# test accuracy: 75.5863539445629 %
# Current learning rate 0.05
# train accuracy: 82.26093138997511 %
# test accuracy: 76.97228144989339 %
# Current learning rate 0.1
# train accuracy: 83.32740846071809 %
# test accuracy: 76.43923240938166 %

# %%
SGD_trained = []

for currLR in learning_rates:
    print(f"Current learning rate {currLR}")
    sgd_with_LR = model(
        X_train, 
        y_train, 
        X_test, 
        y_test, 
        optimization_algorithm=SGD, 
        learning_rate=currLR, 
        print_cost=False,
    )
    SGD_trained.append(sgd_with_LR)
# Out:
# Current learning rate 0.001
# train accuracy: 81.86988979736935 %
# test accuracy: 77.50533049040511 %
# Current learning rate 0.005
# train accuracy: 85.24706718805545 %
# test accuracy: 75.90618336886993 %
# Current learning rate 0.01
# train accuracy: 86.84678279416993 %
# test accuracy: 75.5863539445629 %
# Current learning rate 0.05
# train accuracy: 90.36615712762176 %
# test accuracy: 75.47974413646055 %
# Current learning rate 0.1
# train accuracy: 91.7170280838962 %
# test accuracy: 74.84008528784648 %

# %%
def AdamMa(w, b, X, Y, num_iterations, learning_rate, print_cost=False, beta1=0.9, beta2=0.999, constant=1e-8):
    costs = []
    v_dw, v_db = 0,0
    m_dw, m_db = 0,0
    
    for iteration in range(num_iterations):        
        
        grads, cost = propagate(w,b,X,Y)
        
        # Retrieve derivatives from grads
        dw = grads["dw"]
        db = grads["db"]
        
        
        m_dw = beta1*m_dw + (1-beta1)*dw
        # *** biases *** #
        m_db = beta1*m_db + (1-beta1)*db

        # beta 2
        # weight
        v_dw = beta2*v_dw + (1-beta2)*np.power(dw, 2)
        # bias
        v_db = beta2*v_db + (1-beta2)*np.power(db, 2)

        # bias correction
        m_dw_corr = m_dw/(1-beta1**iteration+1)
        m_db_corr = m_db/(1-beta1**iteration+1)
        v_dw_corr = v_dw/(1-beta2**iteration+1)
        v_db_corr = v_db/(1-beta2**iteration+1)

        # update weights and biases
        w -=  learning_rate*(m_dw_corr/(np.sqrt(v_dw_corr)+constant))
        b -=  learning_rate*(m_db_corr/(np.sqrt(v_db_corr)+constant))
        
        # Record the costs
        if iteration % 100 == 0:
            costs.append(cost)
        
        # Print the cost every 100 training iterations
        if print_cost and iteration % 100 == 0:
            print ("Cost after iteration %i: %f" %(iteration, cost))
        
    params = {"w": w,
              "b": b}
    grads = {"dw": dw,
             "db": db}
    return params, grads, costs

# %%
ADAM_MA_trained = []

for currLR in learning_rates:
    print(f"Current learning rate {currLR}")
    adam_with_LR = model(
        X_train, 
        y_train, 
        X_test, 
        y_test, 
        optimization_algorithm=AdamMa, 
        num_iterations=2000, 
        learning_rate=1e-3, 
        print_cost=True
    )
    ADAM_MA_trained.append(adam_with_LR)
# Out:
# Current learning rate 0.001
# Cost after iteration 0: 0.693147
# Cost after iteration 100: 0.431998
# Cost after iteration 200: 0.393599
# Cost after iteration 300: 0.371449
# Cost after iteration 400: 0.355642
# Cost after iteration 500: 0.343234
# Cost after iteration 600: 0.332953
# Cost after iteration 700: 0.324134
# Cost after iteration 800: 0.316384
# Cost after iteration 900: 0.309455
# Cost after iteration 1000: 0.303175
# Cost after iteration 1100: 0.297422
# Cost after iteration 1200: 0.292108
# Cost after iteration 1300: 0.287164
# Cost after iteration 1400: 0.282536
# Cost after iteration 1500: 0.278182
# Cost after iteration 1600: 0.274067
# Cost after iteration 1700: 0.270165
# Cost after iteration 1800: 0.266452
# Cost after iteration 1900: 0.262908
# train accuracy: 89.90401706363313 %
# test accuracy: 76.11940298507463 %
# Current learning rate 0.005
# Cost after iteration 0: 0.693147
# Cost after iteration 100: 0.431998
# Cost after iteration 200: 0.393599
# Cost after iteration 300: 0.371449
# Cost after iteration 400: 0.355642
# Cost after iteration 500: 0.343234
# Cost after iteration 600: 0.332953
# Cost after iteration 700: 0.324134
# Cost after iteration 800: 0.316384
# Cost after iteration 900: 0.309455
# Cost after iteration 1000: 0.303175
# Cost after iteration 1100: 0.297422
# Cost after iteration 1200: 0.292108
# Cost after iteration 1300: 0.287164
# Cost after iteration 1400: 0.282536
# Cost after iteration 1500: 0.278182
# Cost after iteration 1600: 0.274067
# Cost after iteration 1700: 0.270165
# Cost after iteration 1800: 0.266452
# Cost after iteration 1900: 0.262908
# train accuracy: 89.90401706363313 %
# test accuracy: 76.11940298507463 %
# Current learning rate 0.01
# Cost after iteration 0: 0.693147
# Cost after iteration 100: 0.431998
# Cost after iteration 200: 0.393599
# Cost after iteration 300: 0.371449
# Cost after iteration 400: 0.355642
# Cost after iteration 500: 0.343234
# Cost after iteration 600: 0.332953
# Cost after iteration 700: 0.324134
# Cost after iteration 800: 0.316384
# Cost after iteration 900: 0.309455
# Cost after iteration 1000: 0.303175
# Cost after iteration 1100: 0.297422
# Cost after iteration 1200: 0.292108
# Cost after iteration 1300: 0.287164
# Cost after iteration 1400: 0.282536
# Cost after iteration 1500: 0.278182
# Cost after iteration 1600: 0.274067
# Cost after iteration 1700: 0.270165
# Cost after iteration 1800: 0.266452
# Cost after iteration 1900: 0.262908
# train accuracy: 89.90401706363313 %
# test accuracy: 76.11940298507463 %
# Current learning rate 0.05
# Cost after iteration 0: 0.693147
# Cost after iteration 100: 0.431998
# Cost after iteration 200: 0.393599
# Cost after iteration 300: 0.371449
# Cost after iteration 400: 0.355642
# Cost after iteration 500: 0.343234
# Cost after iteration 600: 0.332953
# Cost after iteration 700: 0.324134
# Cost after iteration 800: 0.316384
# Cost after iteration 900: 0.309455
# Cost after iteration 1000: 0.303175
# Cost after iteration 1100: 0.297422
# Cost after iteration 1200: 0.292108
# Cost after iteration 1300: 0.287164
# Cost after iteration 1400: 0.282536
# Cost after iteration 1500: 0.278182
# Cost after iteration 1600: 0.274067
# Cost after iteration 1700: 0.270165
# Cost after iteration 1800: 0.266452
# Cost after iteration 1900: 0.262908
# train accuracy: 89.90401706363313 %
# test accuracy: 76.11940298507463 %
# Current learning rate 0.1
# Cost after iteration 0: 0.693147
# Cost after iteration 100: 0.431998
# Cost after iteration 200: 0.393599
# Cost after iteration 300: 0.371449
# Cost after iteration 400: 0.355642
# Cost after iteration 500: 0.343234
# Cost after iteration 600: 0.332953
# Cost after iteration 700: 0.324134
# Cost after iteration 800: 0.316384
# Cost after iteration 900: 0.309455
# Cost after iteration 1000: 0.303175
# Cost after iteration 1100: 0.297422
# Cost after iteration 1200: 0.292108
# Cost after iteration 1300: 0.287164
# Cost after iteration 1400: 0.282536
# Cost after iteration 1500: 0.278182
# Cost after iteration 1600: 0.274067
# Cost after iteration 1700: 0.270165
# Cost after iteration 1800: 0.266452
# Cost after iteration 1900: 0.262908
# train accuracy: 89.90401706363313 %
# test accuracy: 76.11940298507463 %

# %%
ADAM_trained = []
# SGD         w, b, X, Y, epochs, learning_rate=1e-1, print_cost=True
# model(X_train, Y_train, X_test, Y_test, num_iterations = 2000, learning_rate = 0.5, print_cost = False, optimization_algorithm=optimize)
for currLR in learning_rates:
    print(f"Current learning rate {currLR}")
    adam_with_LR = model(
        X_train, 
        y_train, 
        X_test, 
        y_test,
        optimization_algorithm=ADAM, 
        learning_rate=currLR, 
        print_cost=False,
    )
    # print(adam_with_LR)
    ADAM_trained.append(adam_with_LR)
# Out:
# Current learning rate 0.001
# train accuracy: 89.93956629932457 %
# test accuracy: 75.5863539445629 %
# Current learning rate 0.005
# train accuracy: 94.02772840383932 %
# test accuracy: 73.56076759061834 %
# Current learning rate 0.01
# train accuracy: 94.52541770351938 %
# test accuracy: 72.49466950959489 %
# Current learning rate 0.05
# train accuracy: 95.34305012442232 %
# test accuracy: 71.00213219616205 %
# Current learning rate 0.1
# train accuracy: 95.76964095271951 %
# test accuracy: 70.8955223880597 %
# <ipython-input-9-6c9f335037cc>:21: RuntimeWarning:
#
# divide by zero encountered in log
#
# <ipython-input-9-6c9f335037cc>:21: RuntimeWarning:
#
# invalid value encountered in multiply

# %%
type(GD_trained[0]["costs"][0])
# Out:
# numpy.float64

# %%
type(SGD_trained[0]["costs"][0])#["costs"]
# Out:
# numpy.ndarray

# %%
# Conver slice of sigle numpy.ndarray to slice
list_SGD_costs = []
for idx in range(len(learning_rates)):
    cst = []
    for elem in SGD_trained[idx]["costs"]:
        cst.append(elem[0])
    list_SGD_costs.append(cst)
# Out:
# Converetd slices size 5, 5

# %%
list_ADAM_costs = []
for idx in range(len(learning_rates)):
    cst = []
    for elem in ADAM_trained[idx]["costs"]:
        cst.append(elem[0])
    list_ADAM_costs.append(cst)

# %%
fig = go.Figure()
for idx, currLR in enumerate(learning_rates):
    fig.add_trace(
        go.Line(
            y=GD_trained[idx]["costs"],
            name=currLR,
        ), 
    )

fig.update_layout(title_text="Gradient Descent", legend_title="Learning rate")
fig.update_xaxes(title="Iteration")
fig.update_yaxes(title="Loss")
fig.show()

# %%
fig = go.Figure()
for idx, currLR in enumerate(learning_rates):
    fig.add_trace(
        go.Line(
            y=list_SGD_costs[idx],
            name=currLR,
        ), 
    )

fig.update_layout(title_text="Stochastic Gradient Descent", legend_title="Learning rate")
fig.update_xaxes(title="Epoch")
fig.update_yaxes(title="Loss")

fig.show()

# %%
fig = go.Figure()
for idx, currLR in enumerate(learning_rates):
    fig.add_trace(
        go.Line(
            y=list_ADAM_costs[idx],
            name=currLR,
        ), 
    )

fig.update_layout(title_text="ADAM", legend_title="Learning rate")
fig.update_xaxes(title="Epoch")
fig.update_yaxes(title="Loss")
fig.show()

# %% [markdown]
# ### 4.	Compare the accuracy of the models fitted with various BP algorithms.
#
# All of three optimization algorithms `Gradient Descent`, `Stochastic Gradient Descent` and  `Adam` showed their best performance depending on current learning rate.
#
# As it shown in the tables with the inctrase of step of LR `Adam` drops accuracy on test, however `GD` is totally opposite.
#
# Also, `Stochastic Gradient Descent` has a noisy Loss output, so why we cannot be certain what is the optimal value of learning rate for such an algorithm, but overall it has the best accuracy with smaller LR. But it's stable

# %% [markdown]
# **Table 1. Algorithms accuracy with the LR = 0.001**
# |Algorithm | train | test |
# |:------:|:------:|:------:|
# |GD      | 72.52044081052257 %| 72.70788912579957 %|
# |SGD     |81.86988979736935 %|**77.50533049040511 %**|
# |ADAM    |**89.93956629932457 %**|75.5863539445629 %|

# %% [markdown]
# **Table 2. Algorithms accuracy with the LR = 0.005**
# |Algorithm | train | test |
# |:------:|:------:|:------:|
# |GD      | 77.10629221471739  %| 74.73347547974413 %|
# |SGD     |85.24706718805545 %|**75.90618336886993 %**|
# |ADAM    |**94.02772840383932 %**|73.56076759061834 %|

# %% [markdown]
# **Table 3. Algorithms accuracy with the LR = 0.01**
# |Algorithm | train | test |
# |:------:|:------:|:------:|
# |GD      | 78.35051546391753 %|**75.5863539445629 %**|
# |SGD     | 86.84678279416993 %|**75.5863539445629 %**|
# |ADAM    | **94.52541770351938 %**|72.49466950959489 %|

# %% [markdown]
# **Table 4. Algorithms accuracy with the LR = 0.05**
# |Algorithm | train | test |
# |:------:|:------:|:------:|
# |GD      | 82.26093138997511 %| **76.97228144989339 %**|
# |SGD     | 90.36615712762176 %| 75.47974413646055 %|
# |ADAM    | **95.34305012442232 %**|71.00213219616205 %|

# %% [markdown]
# **Table 5. Algorithms accuracy with the LR = 0.1**
# |Algorithm | train | test |
# |:------:|:------:|:------:|
# |GD      | 83.32740846071809 %| **76.43923240938166 %**|
# |SGD     |91.7170280838962 %|74.84008528784648 %|
# |ADAM    |**95.76964095271951 %**|70.8955223880597 %|
